# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import GPy
import pickle
import math
import json

with open('datapoints_dict.pkl', 'rb') as f:
    data = pickle.load(f)
    
formfactors = []
densities = []

for key in data:
    if not isinstance(data[key]['form_factor'], float) and not isinstance(data[key]['total_density'], float):
        formfactors.append(data[key]['form_factor'])
        densities.append(data[key]['total_density'].to_numpy())
        
formfactors = np.array(formfactors)
densities = np.array(densities)

outlier_column_indexes = [387, 261, 10, 16, 277, 24, 32, 34, 419, 37, 38, 551, 43, 430, 303, 311, 583, 78, 82, 89, 221, 353, 364, 118, 252, 175, 176, 229, 392, 567]
densities = np.delete(densities, outlier_column_indexes)
formfactors = np.delete(formfactors, outlier_column_indexes, axis=0)
# Out:
#  /tmp/ipykernel_306600/2013470714.py:20: VisibleDeprecationWarning:Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
def get_cutoff_inds(td, slope_cutoff=10, amt_cutoff=5, tail_len=15):
    l = len(td)
    li = 0
    ri = -1
    
    count = 0
    for i in range(l):
        xi = td[i]
        xj = td[i+1]
        kk = (xj[1] - xi[1]) / (xj[0] - xi[0])
        
        if kk > slope_cutoff:
            count += 1
        else:
            count = 0
            
        if count >= amt_cutoff:
            li = max(0, i - tail_len)
            break
            
    count = 0
    for i in range(1, l):
        xi = td[-i]
        xj = td[-i-1]
        kk = (xj[1] - xi[1]) / (xi[0] - xj[0])
        
        if kk > slope_cutoff:
            count += 1
        else:
            count = 0
            
        if count >= amt_cutoff:
            ri = min(-1, -i + tail_len)
            break
            
    return li, ri


cut_dens = []

for d in densities:
    li, ri = get_cutoff_inds(d)
    mi = math.floor(np.abs(li - ri) / 2)
    
    if mi > 0:
        cut_dens.append(d[mi:-mi])
    else:
        cut_dens.append(d)
        
densities = np.array(cut_dens)
# Out:
#  /tmp/ipykernel_306600/1259226132.py:50: VisibleDeprecationWarning:Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
interpolated_densities = []

for i, d in enumerate(densities):
    d_x = d[:, 0].reshape(-1, 1)
    d_y = d[:, 1].reshape(-1, 1)

    kernel = GPy.kern.RBF(input_dim=1, variance=1, lengthscale=1)
    m = GPy.models.GPRegression(d_x, d_y, kernel)
    m.optimize(messages=True)
    m.optimize_restarts(num_restarts = 5)
    N = 200
    xrange = np.linspace(min(d_x), max(d_x), N)
    ypred = m.predict(xrange)[0]
    interpolated_densities.append(np.hstack((xrange, ypred)))
    
    print(f"\n{i+1}/{len(densities)} done\n")
# Out:
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s09  0003   1.398961e+05   1.852194e+09
#     00s12  0006   5.024271e+04   6.407064e+07
#     00s16  0009   2.244577e+04   1.813057e+06
#     00s19  0011   1.308517e+04   1.975510e+06
#     00s77  0108   2.608408e+02   8.024662e-07
# Runtime:     00s77
# Optimization status: Converged
#
# Optimization restart 1/5, f = 260.84081327818666
# Optimization restart 2/5, f = 262.56767801368096
# Optimization restart 3/5, f = 469.3481062411719
# Optimization restart 4/5, f = 260.8408132773354
# Optimization restart 5/5, f = 260.84081328267337
#
# 1/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s06  0002   1.321342e+05   2.899226e+09
#     00s18  0009   1.612285e+04   1.655132e+06
#     00s69  0112   2.945449e+02   2.467096e-06
# Runtime:     00s69
# Optimization status: Converged
#
# Optimization restart 1/5, f = 294.54493510093687
# Optimization restart 2/5, f = 294.5449350982552
# Optimization restart 3/5, f = 294.54493510136456
# Optimization restart 4/5, f = 782.0071841986578
# Optimization restart 5/5, f = 294.5449355341285
#
# 2/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s06  0003   1.192036e+05   1.460657e+09
#     00s19  0008   2.541959e+04   4.199986e+06
#     01s20  0110   3.031013e+02   2.526255e+05
#     01s43  0125   2.073627e+02   1.684809e-08
# Runtime:     01s43
# Optimization status: Converged
#
# Optimization restart 1/5, f = 207.36267193287446
# Optimization restart 2/5, f = 569.5984646220362
# Optimization restart 3/5, f = 206.7346459329406
# Optimization restart 4/5, f = 206.73464593889906
# Optimization restart 5/5, f = 206.73464593471027
#
# 3/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s12  0005   4.750337e+04   1.004465e+08
#     00s19  0009   1.555856e+04   1.229786e+06
#     00s83  0123   3.436389e+02   1.854458e-05
# Runtime:     00s83
# Optimization status: Converged
#
# Optimization restart 1/5, f = 319.0594384910921
# Optimization restart 2/5, f = 779.3488846939715
# Optimization restart 3/5, f = 511.6956016677768
# Optimization restart 4/5, f = 319.0594384907512
# Optimization restart 5/5, f = 319.0594384909202
#
# 4/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s19  0008   2.110559e+04   3.278411e+06
#     00s92  0110   2.602106e+02   4.051122e-06
# Runtime:     00s92
# Optimization status: Converged
#
# Optimization restart 1/5, f = 260.21061801815165
# Optimization restart 2/5, f = 606.0295671890105
# Optimization restart 3/5, f = 246.8736347592454
# Optimization restart 4/5, f = 246.873634758829
# Optimization restart 5/5, f = 246.8736347591968
#
# 5/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s11  0005   4.767597e+04   1.942163e+08
#     00s19  0009   1.496166e+04   1.532245e+06
#     00s87  0121   3.241030e+02   1.161114e-05
# Runtime:     00s87
# Optimization status: Converged
#
# Optimization restart 1/5, f = 324.1029645354393
# Optimization restart 2/5, f = 304.8705445262035
# Optimization restart 3/5, f = 312.4567975647328
# Optimization restart 4/5, f = 304.8705444918093
# Optimization restart 5/5, f = 316.94906895096665
#
# 6/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s13  0006   4.042852e+04   7.149378e+07
#     00s19  0009   1.692182e+04   1.758592e+06
#     00s89  0104   5.038104e+02   5.623512e-05
# Runtime:     00s89
# Optimization status: Converged
#
# Optimization restart 1/5, f = 369.1236494676182
# Optimization restart 2/5, f = 369.1236494674234
# Optimization restart 3/5, f = 672.7016520786284
# Optimization restart 4/5, f = 394.24132175504195
# Optimization restart 5/5, f = 369.12364946959815
#
# 7/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s07  0003   9.875901e+04   1.003619e+09
#     00s17  0008   2.146934e+04   3.608705e+06
#     00s19  0010   1.229040e+04   3.148627e+05
#     00s95  0114   3.774002e+02   2.353430e-06
# Runtime:     00s95
# Optimization status: Converged
#
# Optimization restart 1/5, f = 377.4002380704545
# Optimization restart 2/5, f = 377.40023806816276
# Optimization restart 3/5, f = 410.0645424817537
# Optimization restart 4/5, f = 377.4002380681634
# Optimization restart 5/5, f = 377.40023883092266
#
# 8/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s19  0010   1.409853e+04   1.864781e+06
#     00s91  0115   2.459872e+02   2.667169e-08
# Runtime:     00s91
# Optimization status: Converged
#
# Optimization restart 1/5, f = 245.98720028949427
# Optimization restart 2/5, f = 245.98720029218634
# Optimization restart 3/5, f = 245.98720029547127
# Optimization restart 4/5, f = 245.98720029067206
# Optimization restart 5/5, f = 245.9872002911838
#
# 9/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s09  0004   7.105752e+04   3.218638e+08
#     00s19  0008   2.150465e+04   4.950398e+06
#     01s11  0161   2.039888e+02   3.887583e-12
# Runtime:     01s11
# Optimization status: Converged
#
# Optimization restart 1/5, f = 203.9887798871677
# Optimization restart 2/5, f = 232.00956933528454
# Optimization restart 3/5, f = 217.2168678871118
# Optimization restart 4/5, f = 203.9887798892967
# Optimization restart 5/5, f = 203.98877989025678
#
# 10/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s15  0004   8.008441e+04   4.404290e+08
#     00s18  0005   5.955729e+04   3.724261e+08
#     01s13  0137   2.976438e+02   2.212535e-06
# Runtime:     01s13
# Optimization status: Converged
#
# Optimization restart 1/5, f = 297.6438446498896
# Optimization restart 2/5, f = 291.7257969914284
# Optimization restart 3/5, f = 426.78736986577144
# Optimization restart 4/5, f = 967.4232365566514
# Optimization restart 5/5, f = 287.5869744697561
#
# 11/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s06  0002   1.280777e+05   2.599909e+09
#     00s18  0008   2.006535e+04   5.729078e+06
#     01s06  0131   3.660902e+02   7.841653e-05
# Runtime:     01s06
# Optimization status: Converged
#
# Optimization restart 1/5, f = 325.89413060879906
# Optimization restart 2/5, f = 325.8941305470967
# Optimization restart 3/5, f = 325.8941305486258
# Optimization restart 4/5, f = 325.89413054768494
# Optimization restart 5/5, f = 809.1692224673974
#
# 12/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s06  0002   1.255823e+05   3.104680e+09
#     00s18  0008   1.977650e+04   2.898622e+06
#     00s19  0009   1.503008e+04   1.526941e+06
#     00s89  0101   1.701366e+02   1.214256e-05
# Runtime:     00s89
# Optimization status: Converged
#
# Optimization restart 1/5, f = 170.1366341537718
# Optimization restart 2/5, f = 159.9390727775861
# Optimization restart 3/5, f = 164.90688583621827
# Optimization restart 4/5, f = 151.07444798765565
# Optimization restart 5/5, f = 151.07444798894392
#
# 13/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s02  0001   2.345682e+05   1.743644e+10
#     00s18  0008   2.308934e+04   3.492029e+06
#     01s06  0114   3.091906e+02   1.863748e-07
# Runtime:     01s06
# Optimization status: Converged
#
# Optimization restart 1/5, f = 309.19063872043614
# Optimization restart 2/5, f = 309.19063878814904
# Optimization restart 3/5, f = 343.8387647589518
# Optimization restart 4/5, f = 329.5538743757527
# Optimization restart 5/5, f = 309.1906387212666
#
# 14/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s10  0004   8.145648e+04   3.889985e+08
#     00s18  0008   2.522325e+04   4.667230e+06
#     00s99  0099   3.760925e+02   5.461081e-05
# Runtime:     00s99
# Optimization status: Converged
#
# Optimization restart 1/5, f = 376.09252507583096
# Optimization restart 2/5, f = 1035.4662463140332
# Optimization restart 3/5, f = 376.09252473813837
# Optimization restart 4/5, f = 437.1809807808965
# Optimization restart 5/5, f = 423.38122449342995
#
# 15/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s14  0004   6.923496e+04   3.249618e+08
#     00s18  0006   3.697806e+04   2.791681e+07
#     00s19  0007   2.851634e+04   9.526667e+06
#     00s45  0036   8.778429e+02   1.449708e+02
# Runtime:     00s45
# Optimization status: Converged
#
# Optimization restart 1/5, f = 223.6965518956474
# Optimization restart 2/5, f = 253.8242908983795
# Optimization restart 3/5, f = 223.696551892176
# Optimization restart 4/5, f = 223.69655197612303
# Optimization restart 5/5, f = 223.69655189346742
#
# 16/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s18  0007   2.842101e+04   1.001026e+07
#     00s72  0089   1.209115e+02   2.298702e-06
# Runtime:     00s72
# Optimization status: Converged
#
# Optimization restart 1/5, f = 120.91151682607286
# Optimization restart 2/5, f = 120.91151681066465
# Optimization restart 3/5, f = 120.9115168106075
# Optimization restart 4/5, f = 124.24588981990736
# Optimization restart 5/5, f = 412.63222182901075
#
# 17/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s11  0004   8.306066e+04   4.278908e+08
#     00s18  0008   2.576791e+04   4.078867e+06
#     01s09  0131   2.420343e+02   5.573597e-07
# Runtime:     01s09
# Optimization status: Converged
#
# Optimization restart 1/5, f = 242.0343481876633
# Optimization restart 2/5, f = 236.6260569977121
# Optimization restart 3/5, f = 240.95386595727504
# Optimization restart 4/5, f = 236.62605699667904
# Optimization restart 5/5, f = 236.62605699535675
#
# 18/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s07  0003   9.544624e+04   1.148536e+09
#     00s14  0006   3.444908e+04   4.685768e+07
#     00s17  0007   2.587243e+04   8.728148e+06
#     00s84  0100   1.112824e+02   1.921962e-04
# Runtime:     00s84
# Optimization status: Converged
#
# Optimization restart 1/5, f = 111.28239290760018
# Optimization restart 2/5, f = 113.01721999251953
# Optimization restart 3/5, f = 377.91244100687396
# Optimization restart 4/5, f = 111.28239203438036
# Optimization restart 5/5, f = 111.28239205434278
#
# 19/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s07  0002   1.459817e+05   3.323298e+09
#     00s19  0007   3.179054e+04   4.850362e+07
#     01s06  0126   1.960809e+02   7.592143e-08
# Runtime:     01s06
# Optimization status: Converged
#
# Optimization restart 1/5, f = 196.08087607768343
# Optimization restart 2/5, f = 196.97881809622527
# Optimization restart 3/5, f = 210.66527368956395
# Optimization restart 4/5, f = 196.75268724800924
# Optimization restart 5/5, f = 202.60578356975984
#
# 20/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s03  0001   2.013508e+05   1.886718e+10
#     00s11  0005   4.439951e+04   1.081108e+08
#     00s18  0009   1.387185e+04   4.620824e+06
#     00s95  0111   1.773342e+02   1.981165e-04
# Runtime:     00s95
# Optimization status: Converged
#
# Optimization restart 1/5, f = 129.1355775891417
# Optimization restart 2/5, f = 446.2230118345051
# Optimization restart 3/5, f = 824.0461421694065
# Optimization restart 4/5, f = 129.1355775967345
# Optimization restart 5/5, f = 129.13557762026943
#
# 21/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s17  0005   6.078840e+04   1.237924e+08
#     01s17  0102   6.259797e+02   2.386205e+05
#     01s45  0134   4.387996e+02   5.490581e-06
# Runtime:     01s45
# Optimization status: Converged
#
# Optimization restart 1/5, f = 438.7996185633323
# Optimization restart 2/5, f = 427.32306261664667
# Optimization restart 3/5, f = 423.7097503921925
# Optimization restart 4/5, f = 602.7908098206932
# Optimization restart 5/5, f = 508.85893099523696
#
# 22/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s10  0003   1.006555e+05   1.308037e+09
#     00s16  0006   3.762231e+04   3.521993e+07
#     00s19  0007   2.840759e+04   1.528000e+07
#     00s92  0102   8.245798e+01   3.163922e-07
# Runtime:     00s92
# Optimization status: Converged
#
# Optimization restart 1/5, f = 82.45797996412153
# Optimization restart 2/5, f = 103.9065883534995
# Optimization restart 3/5, f = 133.5947707517795
# Optimization restart 4/5, f = 243.4741473326638
# Optimization restart 5/5, f = 98.58941140768181
#
# 23/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s15  0005   4.379767e+04   8.430370e+07
#     00s49  0047   8.147861e+02   2.465949e-11
# Runtime:     00s49
# Optimization status: Converged
#
# Optimization restart 1/5, f = 814.7860595311976
# Optimization restart 2/5, f = 298.4859916999829
# Optimization restart 3/5, f = 307.59461910664066
# Optimization restart 4/5, f = 298.4859916961247
# Optimization restart 5/5, f = 305.8612810240126
#
# 24/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s10  0004   8.677418e+04   4.095411e+08
#     00s18  0008   2.711476e+04   7.978155e+06
#     00s19  0009   2.040593e+04   1.588153e+06
#     01s07  0130   4.077191e+02   1.010733e-06
# Runtime:     01s07
# Optimization status: Converged
#
# Optimization restart 1/5, f = 407.7190983933278
# Optimization restart 2/5, f = 400.3020469579302
# Optimization restart 3/5, f = 408.37123883184387
# Optimization restart 4/5, f = 400.30204695812574
# Optimization restart 5/5, f = 400.302046976613
#
# 25/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s07  0002   1.308123e+05   2.861830e+09
#     00s18  0006   3.574436e+04   3.117405e+07
#     00s93  0095   3.356335e+02   2.457349e-09
# Runtime:     00s93
# Optimization status: Converged
#
# Optimization restart 1/5, f = 335.6334621377773
# Optimization restart 2/5, f = 346.5290375862464
# Optimization restart 3/5, f = 335.6334621387881
# Optimization restart 4/5, f = 335.6334621378898
# Optimization restart 5/5, f = 379.1476677135971
#
# 26/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s04  0001   2.173896e+05   1.722687e+10
#     00s16  0007   2.841015e+04   2.377314e+07
#     01s16  0127   3.858107e+02   8.653273e+03
#     01s31  0143   2.837093e+02   1.807191e-06
# Runtime:     01s31
# Optimization status: Converged
#
# Optimization restart 1/5, f = 283.7093239874829
# Optimization restart 2/5, f = 278.68004630488895
# Optimization restart 3/5, f = 691.6392828379221
# Optimization restart 4/5, f = 278.6800463061264
# Optimization restart 5/5, f = 286.32004447502953
#
# 27/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s04  0001   2.256185e+05   1.904633e+10
#     00s15  0006   4.001004e+04   1.135132e+08
#     00s19  0008   2.248203e+04   6.709310e+06
#     00s95  0112   1.883851e+02   2.322291e-06
# Runtime:     00s95
# Optimization status: Converged
#
# Optimization restart 1/5, f = 188.38507100485603
# Optimization restart 2/5, f = 178.78183765657775
# Optimization restart 3/5, f = 178.78183766159162
# Optimization restart 4/5, f = 308.65872302423605
# Optimization restart 5/5, f = 178.78183765257148
#
# 28/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s15  0005   5.088477e+04   2.332014e+08
#     00s17  0006   3.748122e+04   3.739116e+07
#     01s14  0140   2.993739e+02   1.899924e-07
# Runtime:     01s14
# Optimization status: Converged
#
# Optimization restart 1/5, f = 299.3739485516645
# Optimization restart 2/5, f = 312.1877505766622
# Optimization restart 3/5, f = 299.3739490572571
# Optimization restart 4/5, f = 812.4857700536182
# Optimization restart 5/5, f = 299.3739485573813
#
# 29/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s06  0002   1.233029e+05   2.589982e+09
#     00s13  0005   4.797378e+04   1.843377e+08
#     00s18  0009   1.505528e+04   1.389933e+06
#     00s86  0098   2.712173e+02   1.013737e-05
# Runtime:     00s86
# Optimization status: Converged
#
# Optimization restart 1/5, f = 271.21729645942764
# Optimization restart 2/5, f = 271.21729643768276
# Optimization restart 3/5, f = 271.2172964358343
# Optimization restart 4/5, f = 285.0355070943714
# Optimization restart 5/5, f = 271.21729650647313
#
# 30/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s10  0003   1.068727e+05   1.211540e+09
#     00s18  0007   2.959151e+04   1.523887e+07
#     00s96  0104   2.309203e+02   5.209908e-08
# Runtime:     00s96
# Optimization status: Converged
#
# Optimization restart 1/5, f = 230.92030221110454
# Optimization restart 2/5, f = 230.92030248043923
# Optimization restart 3/5, f = 230.92030221207943
# Optimization restart 4/5, f = 230.92030221582948
# Optimization restart 5/5, f = 230.92030223205717
#
# 31/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s05  0002   1.396278e+05   3.188753e+09
#     00s19  0007   2.984597e+04   1.123479e+07
#     00s96  0124   2.483367e+02   7.823164e-07
# Runtime:     00s96
# Optimization status: Converged
#
# Optimization restart 1/5, f = 248.33670690869974
# Optimization restart 2/5, f = 472.51396664364313
# Optimization restart 3/5, f = 248.94353188213083
# Optimization restart 4/5, f = 242.1703840277052
# Optimization restart 5/5, f = 242.17038402303098
#
# 32/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s10  0003   1.130961e+05   1.289476e+09
#     00s16  0006   4.144009e+04   3.156481e+07
#     01s05  0117   3.900466e+02   9.199648e-06
# Runtime:     01s05
# Optimization status: Converged
#
# Optimization restart 1/5, f = 370.6501688077966
# Optimization restart 2/5, f = 847.1097930415926
# Optimization restart 3/5, f = 391.07967663795637
# Optimization restart 4/5, f = 847.0910797088483
# Optimization restart 5/5, f = 378.50068482521937
#
# 33/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s15  0009   1.519375e+04   2.006346e+06
#     00s18  0011   8.819919e+03   3.321322e+05
#     01s00  0133   2.614188e+02   4.880585e-06
# Runtime:     01s00
# Optimization status: Converged
#
# Optimization restart 1/5, f = 261.41881856785585
# Optimization restart 2/5, f = 255.86577434533675
# Optimization restart 3/5, f = 248.84104920497202
# Optimization restart 4/5, f = 248.84104920568342
# Optimization restart 5/5, f = 248.84104920866042
#
# 34/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s15  0004   6.919578e+04   3.381235e+08
#     00s16  0005   5.150500e+04   2.762206e+08
#     01s16  0129   2.453303e+02   5.551892e+03
#     01s41  0154   1.344833e+02   1.304870e-10
# Runtime:     01s41
# Optimization status: Converged
#
# Optimization restart 1/5, f = 134.48329372383427
# Optimization restart 2/5, f = 134.48329372492347
# Optimization restart 3/5, f = 147.2472431278881
# Optimization restart 4/5, f = 134.48329371495265
# Optimization restart 5/5, f = 134.48329375751766
#
# 35/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s16  0006   3.463047e+04   5.872066e+07
#     01s17  0137   2.569697e+02   3.118243e+01
#     01s63  0200   2.073422e+02   6.246673e-08
# Runtime:     01s63
# Optimization status: Converged
#
# Optimization restart 1/5, f = 207.3421823676346
# Optimization restart 2/5, f = 304.68006985365497
# Optimization restart 3/5, f = 207.34218237443568
# Optimization restart 4/5, f = 207.34218237451813
# Optimization restart 5/5, f = 476.48804821688896
#
# 36/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s05  0001   2.171137e+05   1.945970e+10
#     00s19  0005   5.007400e+04   2.476399e+08
#     00s82  0096   1.910235e+02   4.165833e-05
# Runtime:     00s82
# Optimization status: Converged
#
# Optimization restart 1/5, f = 191.02351445461488
# Optimization restart 2/5, f = 592.8072743751047
# Optimization restart 3/5, f = 355.1790927625386
# Optimization restart 4/5, f = 191.02351420093459
# Optimization restart 5/5, f = 191.02351420141798
#
# 37/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s18  0007   2.909599e+04   1.407698e+07
#     00s19  0008   2.231887e+04   9.190036e+06
#     00s46  0058   4.954713e+02   4.865076e-11
# Runtime:     00s46
# Optimization status: Converged
#
# Optimization restart 1/5, f = 495.4713447643977
# Optimization restart 2/5, f = 495.61168437820027
# Optimization restart 3/5, f = 495.4766795760847
# Optimization restart 4/5, f = 495.5910402955295
# Optimization restart 5/5, f = 495.4850586330408
#
# 38/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s13  0005   5.245130e+04   1.088834e+08
#     00s19  0009   1.762404e+04   1.411963e+06
#     00s65  0079   6.678177e+02   2.012988e-08
# Runtime:     00s65
# Optimization status: Converged
#
# Optimization restart 1/5, f = 667.8177096226575
# Optimization restart 2/5, f = 667.8177096214137
# Optimization restart 3/5, f = 667.8177096372112
# Optimization restart 4/5, f = 774.8847406679378
# Optimization restart 5/5, f = 667.817709621854
#
# 39/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s00  0000   2.164736e+05           nan
#     00s18  0005   4.959645e+04   2.199151e+08
#     01s19  0123   2.499749e+02   4.890013e-06
# Runtime:     01s19
# Optimization status: Converged
#
# Optimization restart 1/5, f = 249.97494296391403
# Optimization restart 2/5, f = 235.6596760040759
# Optimization restart 3/5, f = 249.89685088376558
# Optimization restart 4/5, f = 235.65967600299672
# Optimization restart 5/5, f = 235.65967600621119
#
# 40/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s08  0003   1.323738e+05   1.621115e+09
#     00s12  0005   6.810369e+04   1.440079e+08
#     00s18  0008   2.747533e+04   4.039392e+06
#     01s15  0142   3.447404e+02   1.034586e-06
# Runtime:     01s15
# Optimization status: Converged
#
# Optimization restart 1/5, f = 344.7403529973982
# Optimization restart 2/5, f = 337.3810605552786
# Optimization restart 3/5, f = 337.381060555364
# Optimization restart 4/5, f = 339.58000565582716
# Optimization restart 5/5, f = 337.7406127719561
#
# 41/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s18  0006   3.839247e+04   3.229600e+07
#     01s18  0110   2.888071e+02   3.286494e-07
# Runtime:     01s18
# Optimization status: Converged
#
# Optimization restart 1/5, f = 288.8070535331039
# Optimization restart 2/5, f = 301.15383328494715
# Optimization restart 3/5, f = 288.8070535331125
# Optimization restart 4/5, f = 290.98491348729857
# Optimization restart 5/5, f = 305.4963188284421
#
# 42/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s17  0006   4.947323e+04   3.010613e+08
#     00s19  0007   3.630121e+04   2.195544e+07
#     00s87  0101   3.718939e+02   6.912771e-09
# Runtime:     00s87
# Optimization status: Converged
#
# Optimization restart 1/5, f = 371.8939372720587
# Optimization restart 2/5, f = 371.8939372745122
# Optimization restart 3/5, f = 497.7782226183608
# Optimization restart 4/5, f = 390.4423047722245
# Optimization restart 5/5, f = 371.8939372718793
#
# 43/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s05  0002   1.341564e+05   3.513302e+09
#     00s10  0006   3.775375e+04   7.154917e+07
#     00s16  0011   9.411193e+03   2.051005e+06
#     00s19  0014   5.312883e+03   1.751933e+06
#     00s39  0047   6.876671e+02   1.211895e-11
# Runtime:     00s39
# Optimization status: Converged
#
# Optimization restart 1/5, f = 687.6671234510382
# Optimization restart 2/5, f = 687.6662218334252
# Optimization restart 3/5, f = 607.1868199881042
# Optimization restart 4/5, f = 607.0119590884229
# Optimization restart 5/5, f = 607.0119590874544
#
# 44/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s13  0004   7.141166e+04   3.552816e+08
#     00s16  0005   5.223319e+04   1.073446e+08
#     00s78  0116   1.656434e+02   4.035674e-06
# Runtime:     00s78
# Optimization status: Converged
#
# Optimization restart 1/5, f = 165.64338562043514
# Optimization restart 2/5, f = 155.92805876586013
# Optimization restart 3/5, f = 155.92805876948944
# Optimization restart 4/5, f = 588.9385919172887
# Optimization restart 5/5, f = 158.90292919294828
#
# 45/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s13  0006   3.735904e+04   4.070183e+07
#     00s19  0008   2.130944e+04   3.410776e+06
#     01s17  0132   1.871721e+02   3.420890e-05
# Runtime:     01s17
# Optimization status: Converged
#
# Optimization restart 1/5, f = 187.1721410478886
# Optimization restart 2/5, f = 194.325432598502
# Optimization restart 3/5, f = 187.17214115223004
# Optimization restart 4/5, f = 732.1380613522235
# Optimization restart 5/5, f = 211.93491100252768
#
# 46/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s15  0004   8.024534e+04   3.958898e+08
#     00s17  0005   5.983706e+04   2.571317e+08
#     00s19  0006   4.177285e+04   4.513507e+07
#     00s87  0097   1.992884e+02   7.658829e-05
# Runtime:     00s87
# Optimization status: Converged
#
# Optimization restart 1/5, f = 199.28837060897783
# Optimization restart 2/5, f = 187.94216344836755
# Optimization restart 3/5, f = 885.6076013870052
# Optimization restart 4/5, f = 199.30084322929284
# Optimization restart 5/5, f = 187.94216343331604
#
# 47/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s08  0004   7.418176e+04   3.749428e+08
#     00s15  0010   1.298917e+04   4.938506e+06
#     00s18  0012   7.779610e+03   4.088694e+04
#     00s85  0107   3.003465e+02   1.212910e-07
# Runtime:     00s85
# Optimization status: Converged
#
# Optimization restart 1/5, f = 300.3465424287974
# Optimization restart 2/5, f = 300.3465424288755
# Optimization restart 3/5, f = 729.6171345783575
# Optimization restart 4/5, f = 834.0645415116643
# Optimization restart 5/5, f = 321.54082513622416
#
# 48/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s09  0004   7.946131e+04   4.087482e+08
#     00s19  0008   2.403144e+04   3.773086e+06
#     01s20  0112   2.961872e+02   5.062187e-05
#     01s24  0114   2.961872e+02   7.028930e-06
# Runtime:     01s24
# Optimization status: Converged
#
# Optimization restart 1/5, f = 296.18719802799535
# Optimization restart 2/5, f = 296.18719801318525
# Optimization restart 3/5, f = 296.1871980130592
# Optimization restart 4/5, f = 296.187198013355
# Optimization restart 5/5, f = 296.1871980116515
#
# 49/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s02  0001   2.364486e+05   2.734793e+10
#     00s12  0006   3.719941e+04   4.196896e+07
#     00s18  0010   1.253971e+04   2.271607e+06
#     01s05  0115   3.493856e+02   4.331863e-10
# Runtime:     01s05
# Optimization status: Converged
#
# Optimization restart 1/5, f = 349.3856133418473
# Optimization restart 2/5, f = 349.3856133428973
# Optimization restart 3/5, f = 349.3856133778416
# Optimization restart 4/5, f = 349.38561334517453
# Optimization restart 5/5, f = 349.38561334222345
#
# 50/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s19  0005   5.279455e+04   1.849913e+08
#     01s20  0110   5.517540e+02   4.505453e+03
#     01s39  0129   4.201009e+02   9.214841e-06
# Runtime:     01s39
# Optimization status: Converged
#
# Optimization restart 1/5, f = 401.8293369459753
# Optimization restart 2/5, f = 401.8293369456674
# Optimization restart 3/5, f = 401.82933696925153
# Optimization restart 4/5, f = 401.8293369471305
# Optimization restart 5/5, f = 401.829336955793
#
# 51/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s14  0004   8.861182e+04   4.281099e+08
#     00s18  0007   4.138585e+04   2.517365e+08
#     01s08  0120   3.381558e+02   4.375713e-08
# Runtime:     01s08
# Optimization status: Converged
#
# Optimization restart 1/5, f = 338.1558153723563
# Optimization restart 2/5, f = 338.1558153393197
# Optimization restart 3/5, f = 338.15581565125564
# Optimization restart 4/5, f = 910.1407694410875
# Optimization restart 5/5, f = 338.1558153388273
#
# 52/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s09  0005   4.922127e+04   1.601020e+08
#     00s18  0008   2.020455e+04   3.514521e+06
#     01s04  0117   1.219758e+02   1.828336e-07
# Runtime:     01s04
# Optimization status: Converged
#
# Optimization restart 1/5, f = 121.97581583223446
# Optimization restart 2/5, f = 147.36838071431893
# Optimization restart 3/5, f = 121.97581584228027
# Optimization restart 4/5, f = 1485.640226354969
# Optimization restart 5/5, f = 187.96132595828112
#
# 53/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s07  0004   6.258838e+04   2.756016e+08
#     00s18  0010   1.091506e+04   3.690065e+05
#     01s01  0137   1.705262e+02   7.982393e-08
# Runtime:     01s01
# Optimization status: Converged
#
# Optimization restart 1/5, f = 168.870714270511
# Optimization restart 2/5, f = 168.87071426325338
# Optimization restart 3/5, f = 168.87071426640566
# Optimization restart 4/5, f = 168.87071426355396
# Optimization restart 5/5, f = 168.87071425972425
#
# 54/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s06  0002   1.609727e+05   4.086199e+09
#     00s16  0008   2.545402e+04   4.314671e+06
#     00s19  0009   1.933310e+04   1.346273e+06
#     00s86  0101   2.730685e+02   2.138823e-09
# Runtime:     00s86
# Optimization status: Converged
#
# Optimization restart 1/5, f = 273.0685238321355
# Optimization restart 2/5, f = 273.06852384444676
# Optimization restart 3/5, f = 273.0685238294464
# Optimization restart 4/5, f = 273.06852382997647
# Optimization restart 5/5, f = 273.0685238302723
#
# 55/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s10  0004   7.358251e+04   3.492228e+08
#     00s19  0010   1.303703e+04   2.520660e+06
#     00s73  0096   1.869543e+02   1.913608e-07
# Runtime:     00s73
# Optimization status: Converged
#
# Optimization restart 1/5, f = 186.95426180598594
# Optimization restart 2/5, f = 854.3042947590778
# Optimization restart 3/5, f = 187.7712912202354
# Optimization restart 4/5, f = 186.95426181284904
# Optimization restart 5/5, f = 493.8874273521217
#
# 56/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s09  0003   1.079554e+05   1.339470e+09
#     00s16  0005   5.369256e+04   1.257656e+08
#     01s06  0127   2.798423e+02   7.554775e-05
# Runtime:     01s06
# Optimization status: Converged
#
# Optimization restart 1/5, f = 279.842283455546
# Optimization restart 2/5, f = 703.611126823951
# Optimization restart 3/5, f = 814.215093757352
# Optimization restart 4/5, f = 279.8422833252154
# Optimization restart 5/5, f = 279.8511714870117
#
# 57/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s14  0008   2.032763e+04   2.618949e+06
#     00s19  0012   7.369901e+03   2.476401e+06
#     01s07  0133   2.624821e+02   1.305182e-05
# Runtime:     01s07
# Optimization status: Converged
#
# Optimization restart 1/5, f = 242.68576689379657
# Optimization restart 2/5, f = 242.68576694921884
# Optimization restart 3/5, f = 242.6857668960153
# Optimization restart 4/5, f = 242.6857668941104
# Optimization restart 5/5, f = 248.85993978358005
#
# 58/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s08  0002   1.259153e+05   2.683629e+09
#     00s14  0004   6.594144e+04   3.061501e+08
#     00s19  0008   2.026230e+04   3.034740e+06
#     01s00  0110   2.857732e+02   5.556552e-05
# Runtime:     01s00
# Optimization status: Converged
#
# Optimization restart 1/5, f = 251.81020525677164
# Optimization restart 2/5, f = 263.9998132249997
# Optimization restart 3/5, f = 251.81020525656274
# Optimization restart 4/5, f = 258.96770857566423
# Optimization restart 5/5, f = 267.1219580418117
#
# 59/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s15  0007   3.034684e+04   3.570124e+07
#     00s19  0010   1.338801e+04   4.944128e+05
#     01s00  0119   1.707027e+02   2.093116e-05
# Runtime:     01s00
# Optimization status: Converged
#
# Optimization restart 1/5, f = 170.70270080768626
# Optimization restart 2/5, f = 170.70270075064016
# Optimization restart 3/5, f = 177.2227114229111
# Optimization restart 4/5, f = 170.7027007568063
# Optimization restart 5/5, f = 782.5623214222937
#
# 60/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s13  0006   3.552612e+04   3.747083e+07
#     00s18  0007   2.684707e+04   1.008710e+07
#     01s04  0112   1.469866e+02   1.725111e-07
# Runtime:     01s04
# Optimization status: Converged
#
# Optimization restart 1/5, f = 146.98659040785407
# Optimization restart 2/5, f = 146.9865904119794
# Optimization restart 3/5, f = 146.9865904108284
# Optimization restart 4/5, f = 146.98659040679507
# Optimization restart 5/5, f = 146.98659041300238
#
# 61/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s15  0006   3.862655e+04   4.468155e+07
#     00s19  0008   2.205505e+04   3.494634e+06
#     01s08  0101   2.885901e+02   5.602228e-05
# Runtime:     01s08
# Optimization status: Converged
#
# Optimization restart 1/5, f = 288.590112087405
# Optimization restart 2/5, f = 398.6516244930137
# Optimization restart 3/5, f = 255.84066229035204
# Optimization restart 4/5, f = 255.84066228928995
# Optimization restart 5/5, f = 255.84066228925172
#
# 62/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s18  0007   2.717815e+04   9.486659e+06
#     00s99  0112   1.237430e+02   1.220265e-07
# Runtime:     00s99
# Optimization status: Converged
#
# Optimization restart 1/5, f = 123.7430165231328
# Optimization restart 2/5, f = 174.12922792129405
# Optimization restart 3/5, f = 123.74301653471844
# Optimization restart 4/5, f = 123.74301654162137
# Optimization restart 5/5, f = 123.74301653323784
#
# 63/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s15  0005   5.260083e+04   9.235277e+07
#     01s12  0102   3.722490e+02   1.271925e-03
# Runtime:     01s12
# Optimization status: Converged
#
# Optimization restart 1/5, f = 372.24904687002845
# Optimization restart 2/5, f = 372.24904554419595
# Optimization restart 3/5, f = 372.2490456598537
# Optimization restart 4/5, f = 397.4566609727106
# Optimization restart 5/5, f = 372.2490455497058
#
# 64/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s07  0002   1.556979e+05   3.676968e+09
#     00s09  0003   1.161247e+05   1.379615e+09
#     00s16  0008   2.418604e+04   4.576887e+06
#     00s19  0010   1.413563e+04   3.937136e+05
#     01s26  0146   1.772825e+02   3.446564e-08
# Runtime:     01s26
# Optimization status: Converged
#
# Optimization restart 1/5, f = 177.28251352242998
# Optimization restart 2/5, f = 177.28251352277155
# Optimization restart 3/5, f = 177.28251352998512
# Optimization restart 4/5, f = 177.2825135448388
# Optimization restart 5/5, f = 177.28251352808888
#
# 65/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s04  0001   2.323383e+05   1.995657e+10
#     00s13  0005   5.441918e+04   1.079837e+08
#     00s17  0007   2.964793e+04   1.380193e+07
#     00s18  0008   2.307966e+04   3.721851e+06
#     01s18  0150   4.468787e+02   8.966711e+04
# Runtime:     01s18
# Optimization status: ErrorABNORMAL_TERMINATION_IN_LNSRCH
#
# Optimization restart 1/5, f = 446.88406882579403
# Optimization restart 2/5, f = 232.55398902284625
# Optimization restart 3/5, f = 220.0248670536686
# Optimization restart 4/5, f = 219.7247045963095
# Optimization restart 5/5, f = 246.0965818525297
#
# 66/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s05  0001   2.590927e+05   2.311248e+10
#     00s12  0003   1.184570e+05   1.453529e+09
#     00s19  0008   2.481801e+04   3.935477e+06
#     01s18  0148   2.643112e+02   1.994620e-07
# Runtime:     01s18
# Optimization status: Converged
#
# Optimization restart 1/5, f = 264.3112289332124
# Optimization restart 2/5, f = 263.15963088726005
# Optimization restart 3/5, f = 263.3324794291312
# Optimization restart 4/5, f = 263.1596308881832
# Optimization restart 5/5, f = 533.0422718773514
#
# 67/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s18  0007   2.896676e+04   1.691854e+07
#     00s19  0008   2.167112e+04   3.613956e+06
#     01s02  0111   2.948131e+02   3.283531e-06
# Runtime:     01s02
# Optimization status: Converged
#
# Optimization restart 1/5, f = 294.8130949385688
# Optimization restart 2/5, f = 294.8130949364979
# Optimization restart 3/5, f = 294.813094938251
# Optimization restart 4/5, f = 337.5465686078993
# Optimization restart 5/5, f = 294.813094940372
#
# 68/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s04  0001   2.118920e+05   1.874089e+10
#     00s15  0006   3.564339e+04   3.359023e+07
#     00s19  0009   1.550577e+04   9.794003e+05
#     00s83  0103   2.329789e+02   4.841086e-06
# Runtime:     00s83
# Optimization status: Converged
#
# Optimization restart 1/5, f = 232.97888807471446
# Optimization restart 2/5, f = 232.9788880374546
# Optimization restart 3/5, f = 232.97888805683152
# Optimization restart 4/5, f = 233.8124090127264
# Optimization restart 5/5, f = 240.40564974884035
#
# 69/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s17  0009   1.750380e+04   3.375064e+06
#     00s19  0010   1.348776e+04   1.238290e+06
#     00s93  0110   1.394525e+02   1.594323e-04
# Runtime:     00s93
# Optimization status: Converged
#
# Optimization restart 1/5, f = 139.4525119341671
# Optimization restart 2/5, f = 139.45251190578998
# Optimization restart 3/5, f = 153.11245475691953
# Optimization restart 4/5, f = 154.6678229669743
# Optimization restart 5/5, f = 139.45251190858107
#
# 70/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s13  0006   4.202567e+04   4.399100e+07
#     00s18  0007   3.168531e+04   1.266700e+07
#     00s90  0108   1.798953e+02   1.973140e-07
# Runtime:     00s90
# Optimization status: Converged
#
# Optimization restart 1/5, f = 179.89532063095385
# Optimization restart 2/5, f = 179.8953206360233
# Optimization restart 3/5, f = 434.6089298475846
# Optimization restart 4/5, f = 179.89532062643917
# Optimization restart 5/5, f = 179.89532063364413
#
# 71/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s13  0006   3.553239e+04   3.704328e+07
#     00s18  0009   1.582665e+04   1.377746e+06
#     00s74  0066   8.221629e+02   7.606995e+03
# Runtime:     00s74
# Optimization status: Converged
#
# Optimization restart 1/5, f = 241.12865143694683
# Optimization restart 2/5, f = 379.9549557128519
# Optimization restart 3/5, f = 241.12865143732978
# Optimization restart 4/5, f = 241.1286514548988
# Optimization restart 5/5, f = 244.63966913495034
#
# 72/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s15  0008   2.450794e+04   3.642066e+06
#     00s17  0010   1.411142e+04   8.857905e+05
#     00s18  0011   1.085891e+04   3.760905e+05
#     00s84  0099   1.887017e+02   1.755118e-07
# Runtime:     00s84
# Optimization status: Converged
#
# Optimization restart 1/5, f = 188.7016670457274
# Optimization restart 2/5, f = 192.50903427899044
# Optimization restart 3/5, f = 188.70166704776287
# Optimization restart 4/5, f = 205.66490809483759
# Optimization restart 5/5, f = 206.01012049110278
#
# 73/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s13  0004   5.722881e+04   2.138257e+08
#     00s18  0006   3.095577e+04   8.546578e+07
#     01s15  0130   2.417322e+02   1.562904e-08
# Runtime:     01s15
# Optimization status: Converged
#
# Optimization restart 1/5, f = 241.73223150052115
# Optimization restart 2/5, f = 259.28941054849247
# Optimization restart 3/5, f = 811.6684976556004
# Optimization restart 4/5, f = 255.60421581994893
# Optimization restart 5/5, f = 241.73223150039786
#
# 74/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s05  0001   2.490191e+05   2.258850e+10
#     00s19  0006   4.256588e+04   4.872516e+07
#     01s34  0141   2.538802e+02   1.466683e-06
# Runtime:     01s34
# Optimization status: Converged
#
# Optimization restart 1/5, f = 253.88018734345238
# Optimization restart 2/5, f = 256.4528497350383
# Optimization restart 3/5, f = 246.8394902043924
# Optimization restart 4/5, f = 248.859826942386
# Optimization restart 5/5, f = 246.83949020395093
#
# 75/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s11  0002   1.466095e+05   3.532957e+09
#     00s14  0005   5.617336e+04   2.716215e+08
#     00s17  0008   2.339042e+04   3.941103e+06
#     00s18  0009   1.779575e+04   1.596209e+06
#     00s90  0109   2.058634e+02   7.037374e-08
# Runtime:     00s90
# Optimization status: Converged
#
# Optimization restart 1/5, f = 205.86340531053185
# Optimization restart 2/5, f = 205.86340536255736
# Optimization restart 3/5, f = 212.49467887954887
# Optimization restart 4/5, f = 846.2026974387229
# Optimization restart 5/5, f = 205.86340532855803
#
# 76/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s11  0005   4.869783e+04   1.781870e+08
#     00s12  0006   3.518817e+04   2.676896e+07
#     00s19  0012   6.936464e+03   5.242275e+04
#     00s84  0112   3.010713e+02   6.355647e-07
# Runtime:     00s84
# Optimization status: Converged
#
# Optimization restart 1/5, f = 301.07129212922933
# Optimization restart 2/5, f = 301.0712921296077
# Optimization restart 3/5, f = 443.2901574225586
# Optimization restart 4/5, f = 301.777542158639
# Optimization restart 5/5, f = 301.0712921354371
#
# 77/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s05  0001   2.051203e+05   1.294658e+10
#     00s19  0009   1.597720e+04   4.555380e+06
#     01s02  0125   2.161827e+02   8.912013e-08
# Runtime:     01s02
# Optimization status: Converged
#
# Optimization restart 1/5, f = 216.18270337346303
# Optimization restart 2/5, f = 216.18270337529376
# Optimization restart 3/5, f = 232.29729113121834
# Optimization restart 4/5, f = 216.1827033734461
# Optimization restart 5/5, f = 216.18270344812677
#
# 78/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s18  0003   1.156961e+05   1.439859e+09
#     01s00  0115   1.833666e+02   7.397346e-10
# Runtime:     01s00
# Optimization status: Converged
#
# Optimization restart 1/5, f = 183.36664171113256
# Optimization restart 2/5, f = 361.1015308745049
# Optimization restart 3/5, f = 190.55815249459323
# Optimization restart 4/5, f = 189.11311223580492
# Optimization restart 5/5, f = 216.90592548553684
#
# 79/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s09  0002   1.267962e+05   2.744563e+09
#     00s18  0008   2.036051e+04   2.749978e+06
#     00s98  0102   2.636897e+02   2.958562e-07
# Runtime:     00s98
# Optimization status: Converged
#
# Optimization restart 1/5, f = 263.68965995673545
# Optimization restart 2/5, f = 266.01088029019013
# Optimization restart 3/5, f = 263.6896599617972
# Optimization restart 4/5, f = 914.0807517712651
# Optimization restart 5/5, f = 909.4883523610997
#
# 80/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s15  0004   6.891513e+04   3.432277e+08
#     00s19  0006   3.695816e+04   3.173247e+07
#     01s14  0124   1.496482e+02   3.456723e-05
# Runtime:     01s14
# Optimization status: Converged
#
# Optimization restart 1/5, f = 149.64818170781356
# Optimization restart 2/5, f = 132.7949622710579
# Optimization restart 3/5, f = 132.7949622663084
# Optimization restart 4/5, f = 132.7949622587934
# Optimization restart 5/5, f = 202.42964811570036
#
# 81/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s19  0007   3.031632e+04   1.213351e+07
#     01s20  0121   4.991908e+02   2.498630e+06
#     01s39  0142   1.309661e+02   4.344976e-06
# Runtime:     01s39
# Optimization status: Converged
#
# Optimization restart 1/5, f = 130.9661213054581
# Optimization restart 2/5, f = 117.51934402404746
# Optimization restart 3/5, f = 117.51934403296505
# Optimization restart 4/5, f = 137.29962774171108
# Optimization restart 5/5, f = 117.51934402670736
#
# 82/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s17  0003   9.520361e+04   1.050535e+09
#     01s21  0129   3.282192e+02   1.789570e+02
#     01s37  0145   3.240266e+02   8.179085e-08
# Runtime:     01s37
# Optimization status: Converged
#
# Optimization restart 1/5, f = 324.0265651042515
# Optimization restart 2/5, f = 326.40254198070255
# Optimization restart 3/5, f = 326.40254197249766
# Optimization restart 4/5, f = 324.02656510416045
# Optimization restart 5/5, f = 324.0265651174049
#
# 83/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s18  0003   1.158835e+05   1.370619e+09
#     00s19  0004   7.937106e+04   3.794018e+08
#     00s90  0105   2.463887e+02   7.018169e-06
# Runtime:     00s90
# Optimization status: Converged
#
# Optimization restart 1/5, f = 246.3886982353106
# Optimization restart 2/5, f = 241.35895258886399
# Optimization restart 3/5, f = 241.95995378901674
# Optimization restart 4/5, f = 231.5602691253939
# Optimization restart 5/5, f = 230.09758049414108
#
# 84/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s18  0003   8.655091e+04   8.968125e+08
#     00s51  0048   7.715026e+02   1.958345e-13
# Runtime:     00s51
# Optimization status: Converged
#
# Optimization restart 1/5, f = 771.5025988697241
# Optimization restart 2/5, f = 145.99119786382093
# Optimization restart 3/5, f = 155.95790768392115
# Optimization restart 4/5, f = 145.99119786034075
# Optimization restart 5/5, f = 145.99119785494446
#
# 85/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s18  0007   2.383848e+04   6.970663e+06
#     01s24  0130   1.226882e+02   1.245276e-07
# Runtime:     01s24
# Optimization status: Converged
#
# Optimization restart 1/5, f = 122.6881928382565
# Optimization restart 2/5, f = 122.6881928400256
# Optimization restart 3/5, f = 122.68819284153909
# Optimization restart 4/5, f = 175.32876902460777
# Optimization restart 5/5, f = 321.24486918220003
#
# 86/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s12  0003   9.963497e+04   1.051349e+09
#     00s19  0009   1.598801e+04   1.977889e+06
#     00s96  0114   3.218372e+02   3.054406e-07
# Runtime:     00s96
# Optimization status: Converged
#
# Optimization restart 1/5, f = 321.8372372653557
# Optimization restart 2/5, f = 321.8372372550689
# Optimization restart 3/5, f = 588.9024531008771
# ...
#     00s19  0012   6.446818e+03   3.130876e+04
#     01s13  0135   2.129940e+02   3.742779e-07
# Runtime:     01s13
# Optimization status: Converged
#
# Optimization restart 1/5, f = 212.9940061406132
# Optimization restart 2/5, f = 213.0382648523445
# Optimization restart 3/5, f = 212.99400613992248
# Optimization restart 4/5, f = 212.9940061415337
# Optimization restart 5/5, f = 212.99400615098924
#
# 555/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s08  0003   1.053130e+05   1.313063e+09
#     00s16  0009   1.658010e+04   1.808130e+06
#     00s19  0012   7.400653e+03   3.738622e+05
#     00s80  0133   1.617190e+02   6.503589e-08
# Runtime:     00s80
# Optimization status: Converged
#
# Optimization restart 1/5, f = 161.7190182022565
# Optimization restart 2/5, f = 446.2017774429334
# Optimization restart 3/5, f = 188.65388246039407
# Optimization restart 4/5, f = 161.7190182044786
# Optimization restart 5/5, f = 161.71901820783404
#
# 556/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s07  0002   1.225998e+05   2.489289e+09
#     00s19  0009   1.547894e+04   9.692185e+05
#     01s03  0101   2.659313e+02   3.590871e-06
# Runtime:     01s03
# Optimization status: Converged
#
# Optimization restart 1/5, f = 265.9312743328237
# Optimization restart 2/5, f = 265.93127432953196
# Optimization restart 3/5, f = 306.091512134049
# Optimization restart 4/5, f = 265.93127433082395
# Optimization restart 5/5, f = 265.93127433187703
#
# 557/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s14  0005   4.657371e+04   8.407474e+07
#     00s19  0009   1.520861e+04   1.030791e+06
#     00s75  0112   1.569498e+02   1.134638e-07
# Runtime:     00s75
# Optimization status: Converged
#
# Optimization restart 1/5, f = 156.94975874621474
# Optimization restart 2/5, f = 202.46910921952326
# Optimization restart 3/5, f = 397.6920944723185
# Optimization restart 4/5, f = 158.63255719366714
# Optimization restart 5/5, f = 157.61552412260886
#
# 558/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s18  0007   2.873616e+04   1.033873e+07
#     00s19  0008   2.189644e+04   1.431452e+07
#     01s19  0115   3.997609e+02   1.485103e+02
#     01s44  0132   3.652004e+02   7.081933e-06
# Runtime:     01s44
# Optimization status: Converged
#
# Optimization restart 1/5, f = 365.20041635577684
# Optimization restart 2/5, f = 363.3653623544534
# Optimization restart 3/5, f = 363.3653623542988
# Optimization restart 4/5, f = 363.3653623544707
# Optimization restart 5/5, f = 365.90969326649724
#
# 559/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s15  0004   6.228219e+04   2.692771e+08
#     01s31  0112   2.841255e+02   3.463946e-07
# Runtime:     01s31
# Optimization status: Converged
#
# Optimization restart 1/5, f = 284.12546788684045
# Optimization restart 2/5, f = 284.12546788179577
# Optimization restart 3/5, f = 286.78067250132165
# Optimization restart 4/5, f = 284.12546788252814
# Optimization restart 5/5, f = 303.08842913039126
#
# 560/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s14  0006   3.118651e+04   2.595795e+07
#     00s17  0009   1.355054e+04   1.004715e+06
#     00s19  0010   1.029301e+04   3.476050e+05
#     01s19  0072   5.114746e+02   6.129938e+03
#     01s58  0105   1.290241e+02   4.302510e-08
# Runtime:     01s58
# Optimization status: Converged
#
# Optimization restart 1/5, f = 129.0241383512153
# Optimization restart 2/5, f = 129.02413836061464
# Optimization restart 3/5, f = 129.0241383496666
# Optimization restart 4/5, f = 146.5229133095284
# Optimization restart 5/5, f = 129.02413836242707
#
# 561/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s17  0007   2.581905e+04   1.954130e+07
#     01s18  0096   5.700309e+02   3.899391e+05
#     01s85  0136   2.572218e+02   2.281180e-05
# Runtime:     01s85
# Optimization status: Converged
#
# Optimization restart 1/5, f = 257.22184311488286
# Optimization restart 2/5, f = 657.3258777469409
# Optimization restart 3/5, f = 259.86489787890787
# Optimization restart 4/5, f = 236.9772957845704
# Optimization restart 5/5, f = 295.3621945032993
#
# 562/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s18  0005   6.142011e+04   3.371440e+08
#     01s18  0102   5.360964e+02   1.455482e+05
#     01s73  0166   2.060578e+02   1.372513e-06
# Runtime:     01s73
# Optimization status: Converged
#
# Optimization restart 1/5, f = 206.05777299082243
# Optimization restart 2/5, f = 206.05777299136423
# Optimization restart 3/5, f = 444.4728473781881
# Optimization restart 4/5, f = 206.05777299256627
# Optimization restart 5/5, f = 206.05777299290108
#
# 563/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s16  0009   2.001860e+04   4.524963e+06
#     00s19  0010   1.702760e+04   4.433568e+06
#     01s19  0089   5.655352e+02   2.545880e+00
#     01s65  0121   3.005855e+02   1.353671e-06
# Runtime:     01s65
# Optimization status: Converged
#
# Optimization restart 1/5, f = 292.4139811267145
# Optimization restart 2/5, f = 292.4139811334289
# Optimization restart 3/5, f = 357.08183583615903
# Optimization restart 4/5, f = 298.78878622785186
# Optimization restart 5/5, f = 309.92640725127217
#
# 564/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s15  0007   2.743441e+04   9.917732e+06
#     00s19  0009   1.575380e+04   2.626755e+06
#     01s16  0111   8.941651e+01   5.544597e-12
# Runtime:     01s16
# Optimization status: Converged
#
# Optimization restart 1/5, f = 89.41650914494974
# Optimization restart 2/5, f = 89.41650913888819
# Optimization restart 3/5, f = 89.41650914096073
# Optimization restart 4/5, f = 89.41650914378246
# Optimization restart 5/5, f = 574.5582773327153
#
# 565/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s12  0006   6.176201e+04   3.933544e+08
#     00s17  0008   3.552820e+04   7.291450e+06
#     01s19  0093   6.356350e+06   5.567561e+13
#     01s42  0117   3.306390e+02   7.901986e-05
# Runtime:     01s42
# Optimization status: Converged
#
# Optimization restart 1/5, f = 330.6390165897161
# Optimization restart 2/5, f = 330.6390165818632
# Optimization restart 3/5, f = 330.6390166482362
# Optimization restart 4/5, f = 330.6390165965288
# Optimization restart 5/5, f = 330.63901658082955
#
# 566/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s14  0004   7.028140e+04   3.237299e+08
#     00s19  0008   2.127618e+04   3.441513e+06
#     00s75  0073   4.972275e+02   4.383424e+04
# Runtime:     00s75
# Optimization status: Converged
#
# Optimization restart 1/5, f = 284.0284916139458
# Optimization restart 2/5, f = 302.28361191210075
# Optimization restart 3/5, f = 283.46023622578105
# Optimization restart 4/5, f = 510.3126937560876
# Optimization restart 5/5, f = 297.6925074952038
#
# 567/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s18  0003   1.046868e+05   1.368514e+09
#     01s13  0088   6.096197e+02   2.203821e-08
# Runtime:     01s13
# Optimization status: Converged
#
# Optimization restart 1/5, f = 315.88756334740435
# Optimization restart 2/5, f = 609.6197386096476
# Optimization restart 3/5, f = 313.2470025736473
# Optimization restart 4/5, f = 313.2470025735659
# Optimization restart 5/5, f = 609.61973859818
#
# 568/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s13  0001   2.422145e+05   2.012333e+10
#     01s13  0065   6.510107e+02   3.450007e+04
#     01s59  0107   3.997553e+02   1.298823e-06
# Runtime:     01s59
# Optimization status: Converged
#
# Optimization restart 1/5, f = 399.75528368820153
# Optimization restart 2/5, f = 413.77853558242487
# Optimization restart 3/5, f = 399.75528366287904
# Optimization restart 4/5, f = 402.2419880777886
# Optimization restart 5/5, f = 411.2901795576711
#
# 569/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s12  0006   3.956047e+04   3.587524e+07
#     00s17  0010   1.311968e+04   7.889363e+05
#     01s18  0101   3.469379e+02   7.658890e+03
#     01s63  0137   2.715405e+02   1.839320e-09
# Runtime:     01s63
# Optimization status: Converged
#
# Optimization restart 1/5, f = 271.54053738285256
# Optimization restart 2/5, f = 277.8884526487316
# Optimization restart 3/5, f = 273.030750637502
# Optimization restart 4/5, f = 271.54053738385994
# Optimization restart 5/5, f = 309.5294011780311
#
# 570/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s00  0000   2.156008e+05           nan
#     00s19  0007   2.660552e+04   8.805243e+06
#     01s33  0118   1.591918e+02   2.142222e-07
# Runtime:     01s33
# Optimization status: Converged
#
# Optimization restart 1/5, f = 156.2953620166789
# Optimization restart 2/5, f = 167.62854981295743
# Optimization restart 3/5, f = 168.23191382731923
# Optimization restart 4/5, f = 770.7900069726999
# Optimization restart 5/5, f = 784.2002467469548
#
# 571/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s11  0005   4.482225e+04   8.644465e+07
#     00s19  0012   6.421227e+03   9.040871e+05
#     01s02  0105   1.941032e+02   4.126963e-06
# Runtime:     01s02
# Optimization status: Converged
#
# Optimization restart 1/5, f = 181.56893051239462
# Optimization restart 2/5, f = 192.28098509039972
# Optimization restart 3/5, f = 169.69362805618337
# Optimization restart 4/5, f = 169.69362806291662
# Optimization restart 5/5, f = 169.69362806433935
#
# 572/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s19  0006   3.707221e+04   3.766133e+07
#     00s97  0117   2.245006e+02   4.689956e-07
# Runtime:     00s97
# Optimization status: Converged
#
# Optimization restart 1/5, f = 224.5005580528969
# Optimization restart 2/5, f = 365.83070555839174
# Optimization restart 3/5, f = 224.50055805434414
# Optimization restart 4/5, f = 250.40283366134722
# Optimization restart 5/5, f = 224.5005580553774
#
# 573/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s10  0002   1.782342e+05   4.544278e+09
#     00s18  0006   4.855089e+04   7.684243e+07
#     01s17  0144   3.582873e+02   2.010250e-07
# Runtime:     01s17
# Optimization status: Converged
#
# Optimization restart 1/5, f = 358.2873484401845
# Optimization restart 2/5, f = 393.545417583936
# Optimization restart 3/5, f = 358.2913008625285
# Optimization restart 4/5, f = 358.2873484404487
# Optimization restart 5/5, f = 358.28734845700694
#
# 574/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s09  0004   6.922615e+04   2.504805e+08
#     00s17  0009   1.711296e+04   1.017311e+06
#     00s19  0010   1.304279e+04   3.099919e+05
#     01s19  0120   1.153132e+06   8.334691e+12
#     01s49  0149   2.911911e+02   1.278951e-07
# Runtime:     01s49
# Optimization status: Converged
#
# Optimization restart 1/5, f = 291.19106242838905
# Optimization restart 2/5, f = 291.18339401404785
# Optimization restart 3/5, f = 291.18339402130835
# Optimization restart 4/5, f = 291.18339401264546
# Optimization restart 5/5, f = 291.1833940123305
#
# 575/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s09  0002   1.302395e+05   3.159245e+09
#     00s17  0008   2.069607e+04   4.299110e+06
#     00s19  0010   1.200672e+04   7.271453e+05
#     00s94  0125   1.242134e+02   2.732252e-05
# Runtime:     00s94
# Optimization status: Converged
#
# Optimization restart 1/5, f = 124.21335865644451
# Optimization restart 2/5, f = 124.21335866718788
# Optimization restart 3/5, f = 124.21335863128975
# Optimization restart 4/5, f = 141.53757774788053
# Optimization restart 5/5, f = 124.2133586408634
#
# 576/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s10  0004   7.786297e+04   4.041557e+08
#     00s15  0008   2.343421e+04   3.902276e+06
#     00s19  0011   1.034302e+04   3.581885e+05
#     00s88  0100   2.818109e+02   2.489239e-05
# Runtime:     00s88
# Optimization status: Converged
#
# Optimization restart 1/5, f = 281.8109377484911
# Optimization restart 2/5, f = 773.444144779982
# Optimization restart 3/5, f = 371.43464103114445
# Optimization restart 4/5, f = 773.4441447798225
# Optimization restart 5/5, f = 253.85938404044103
#
# 577/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s12  0006   3.730280e+04   4.706417e+07
#     00s19  0012   6.955224e+03   5.588415e+04
#     00s71  0094   2.347224e+02   1.627371e-08
# Runtime:     00s71
# Optimization status: Converged
#
# Optimization restart 1/5, f = 234.7223510555242
# Optimization restart 2/5, f = 582.7723337510668
# Optimization restart 3/5, f = 582.7723337496064
# Optimization restart 4/5, f = 281.4434192694705
# Optimization restart 5/5, f = 582.7723337496172
#
# 578/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s13  0005   5.864912e+04   2.367036e+08
#     00s19  0011   1.082660e+04   1.301609e+05
#     01s19  0142   1.065783e+02   3.378950e-09
# Runtime:     01s19
# Optimization status: Converged
#
# Optimization restart 1/5, f = 106.57834181733199
# Optimization restart 2/5, f = 129.12420511200287
# Optimization restart 3/5, f = 106.57834182299717
# Optimization restart 4/5, f = 583.2275482454936
# Optimization restart 5/5, f = 106.57834182080839
#
# 579/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s14  0004   6.563748e+04   2.646005e+08
#     00s19  0008   2.027872e+04   3.448811e+06
#     00s83  0097   4.063747e+02   1.040428e-07
# Runtime:     00s83
# Optimization status: Converged
#
# Optimization restart 1/5, f = 406.37466441532115
# Optimization restart 2/5, f = 406.37466441443877
# Optimization restart 3/5, f = 406.3746644154114
# Optimization restart 4/5, f = 406.37466441689145
# Optimization restart 5/5, f = 414.34348019439926
#
# 580/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s09  0004   6.562975e+04   2.888994e+08
#     00s14  0008   1.988862e+04   2.951694e+06
#     00s19  0013   5.917842e+03   3.746756e+06
#     01s13  0130   2.973497e+02   3.695287e-07
# Runtime:     01s13
# Optimization status: Converged
#
# Optimization restart 1/5, f = 297.34971688708663
# Optimization restart 2/5, f = 309.1722013639174
# Optimization restart 3/5, f = 394.80055072299365
# Optimization restart 4/5, f = 297.3497168875448
# Optimization restart 5/5, f = 297.3497169209549
#
# 581/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s16  0004   6.815986e+04   3.441008e+08
#     01s17  0101   2.143461e+02   3.206464e+01
#     01s59  0145   6.432199e+01   3.231936e-11
# Runtime:     01s59
# Optimization status: Converged
#
# Optimization restart 1/5, f = 64.32199005797196
# Optimization restart 2/5, f = 64.32199003840125
# Optimization restart 3/5, f = 76.70336830070607
# Optimization restart 4/5, f = 64.32199004690636
# Optimization restart 5/5, f = 64.32199003534825
#
# 582/583 done
#
# Running L-BFGS-B (Scipy implementation) Code:
#   runtime   i      f              |g|
#     00s10  0002   1.282881e+05   2.894631e+09
#     00s19  0008   1.983943e+04   2.334172e+06
#     00s94  0103   3.903522e+02   4.037118e-07
# Runtime:     00s94
# Optimization status: Converged
#
# Optimization restart 1/5, f = 390.3522411142777
# Optimization restart 2/5, f = 390.3522411103323
# Optimization restart 3/5, f = 390.35224110928806
# Optimization restart 4/5, f = 390.352241111721
# Optimization restart 5/5, f = 390.3522411101495
#
# 583/583 done

# %%
data_dict = {}

for i, (ff, iden) in enumerate(list(zip(formfactors, interpolated_densities))):
    data_dict[i] = {'formfactor': ff, 'density': iden}

with open('density_cut.pkl', 'wb') as f:
    pickle.dump(data_dict, f, protocol=pickle.HIGHEST_PROTOCOL)

# %%
json_dict = {}

for i, (ff, iden) in enumerate(list(zip(formfactors, interpolated_densities))):
    xs = iden[:, 0]
    ys = iden[:, 1]
    flattened = list(xs) + list(ys)
    
    json_dict[i] = {'formfactor': list(ff), 'density': flattened}

with open('density_cut.json', 'w') as f:
    json.dump(json_dict, f)
