# %%
import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_json('simulations.json')
df
# Out:
#                                                             1    \
# FormFactor    [[0.0, 65.55879893576454], [0.001, 65.52097170...
# TotalDensity  [[-3.325673177719116, 329.73226830617637], [-3...
# apl           {'100000.0078125': 53.27357482910156, '100010....
# thickness                                               4.53332
#
#                                                             10   \
# FormFactor    [[0.0, 15.572641992998474], [0.001, 15.5513378...
# TotalDensity  [[-3.450615491867065, 333.0026784541281], [-3....
# apl           {'0.0': 64.563232421875, '100.0': 64.105604383...
# thickness                                              3.954219
#
#                                                             100  \
# FormFactor    [[0.0, 17.31605724385449], [0.001, 17.28835138...
# TotalDensity  [[-3.769429035186767, 338.803858596419], [-3.7...
# apl           {'200000.0': 66.04924774169922, '201000.0': 64...
# thickness                                              4.284378
#
#                                                             101  \
# FormFactor    [[0.0, 110.40567832366456], [0.001, 110.363314...
# TotalDensity  [[-4.195182552337647, 329.1754387729644], [-4....
# apl           {'100000.0': 59.64723828125, '100020.0': 60.31...
# thickness                                              4.263213
#
#                                                             102  \
# FormFactor    [[0.0, 20.350167778784467], [0.001, 20.3136954...
# TotalDensity  [[-3.9791937465667733, 338.02738118600615], [-...
# apl           {'0.0': 53.1859921875, '100.0': 54.51705078125...
# thickness                                              4.750032
#
#                                                             103  \
# FormFactor    [[0.0, 46.448371511153624], [0.001, 46.4108264...
# TotalDensity  [[-3.857857280731201, 335.8092781725056], [-3....
# apl           {'100000.0078125': 55.20517349243164, '100010....
# thickness                                              4.621177
#
#                                                             104  \
# FormFactor    [[0.0, 24.2086088496465], [0.001, 24.179531833...
# TotalDensity                                               None
# apl           {'0.0': 53.58509709284856, '1000.0': 51.536926...
# thickness                                              4.449318
#
#                                                             105  \
# FormFactor    [[0.0, 88.86310653323314], [0.001, 88.82051362...
# TotalDensity                                               None
# apl           {'100000.0': 42.48250638521635, '101000.0': 42...
# thickness                                              5.014735
#
#                                                             106  \
# FormFactor    [[0.0, 51.20403098815298], [0.001, 51.22471131...
# TotalDensity  [[-3.704767187118531, 348.98447238425695], [-3...
# apl           {'0.0': 63.3934375, '100.0': 63.0481591796875,...
# thickness                                              4.304981
#
#                                                             107  ...  \
# FormFactor    [[0.0, 86.43591874913768], [0.001, 86.39792434...  ...
# TotalDensity  [[-3.9933083152771003, 328.2203127086868], [-3...  ...
# apl           {'100000.0': 58.94308090209961, '100020.0': 59...  ...
# thickness                                              4.483715  ...
#
#                                                             90   \
# FormFactor    [[0.0, 11.047130902532333], [0.001, 11.0228171...
# TotalDensity  [[-3.809502771377563, 336.60685842181965], [-3...
# apl           {'0.0': 70.46417236328125, '1000.0': 67.105613...
# thickness                                              4.111844
#
#                                                             91   \
# FormFactor    [[0.0, 37.31489781212652], [0.001, 37.27845054...
# TotalDensity  [[-5.496297426223755, 337.8956631964299], [-5....
# apl           {'200000.0': 42.06497802734375, '201000.0': 41...
# thickness                                               4.83444
#
#                                                             92   \
# FormFactor    [[0.0, 54.944601486624], [0.001, 54.9137411479...
# TotalDensity  [[-4.09386212348938, 336.8302036396125], [-4.0...
# apl           {'100010.0': 61.60816955566406, '100020.0': 62...
# thickness                                              4.337281
#
#                                                             93   \
# FormFactor    [[0.0, 123.65124482935424], [0.001, 123.667489...
# TotalDensity  [[-6.400798763275147, 369.7252820960883], [-6....
# apl           {'100000.0': 61.43149739583333, '100020.0': 61...
# thickness                                              4.381295
#
#                                                             94   \
# FormFactor    [[0.0, 11.805258236274504], [0.001, 11.7806061...
# TotalDensity                                               None
# apl           {'100000.0': 65.68218231201172, '101000.0': 64...
# thickness                                               4.19342
#
#                                                             95   \
# FormFactor    [[0.0, 60.04677517642964], [0.001, 60.01194185...
# TotalDensity  [[-3.892557191848754, 337.5673556836723], [-3....
# apl           {'0.0': 62.795857747395836, '20.0': 64.1294826...
# thickness                                               4.46066
#
#                                                             96   \
# FormFactor    [[0.0, 25.40446122064217], [0.001, 25.41730041...
# TotalDensity  [[-3.711015403747558, 323.2462952500889], [-3....
# apl           {'0.0': 61.45030975341797, '10.0': 61.58327102...
# thickness                                                3.5343
#
#                                                             97   \
# FormFactor    [[0.0, 10.71605352767222], [0.001, 10.69036141...
# TotalDensity  [[-3.01549828338623, 335.22777616799317], [-2....
# apl           {'0.0': 61.85429000854492, '50.0': 62.22754669...
# thickness                                              4.218211
#
#                                                             98   \
# FormFactor    [[0.0, 66.80777954803744], [0.001, 66.77450960...
# TotalDensity                                               None
# apl           {'100000.0': 52.769500732421875, '101000.0': 5...
# thickness                                              4.436823
#
#                                                             99
# FormFactor    [[0.0, 19.20982961092257], [0.001, 19.18224157...
# TotalDensity                                               None
# apl           {'100000.0': 63.81878662109375, '101000.0': 63...
# thickness                                              4.262819
#
# [4 rows x 724 columns]

# %%
full_df = df.dropna(axis = 1)
full_df
# Out:
#                                                             1    \
# FormFactor    [[0.0, 65.55879893576454], [0.001, 65.52097170...
# TotalDensity  [[-3.325673177719116, 329.73226830617637], [-3...
# apl           {'100000.0078125': 53.27357482910156, '100010....
# thickness                                               4.53332
#
#                                                             10   \
# FormFactor    [[0.0, 15.572641992998474], [0.001, 15.5513378...
# TotalDensity  [[-3.450615491867065, 333.0026784541281], [-3....
# apl           {'0.0': 64.563232421875, '100.0': 64.105604383...
# thickness                                              3.954219
#
#                                                             100  \
# FormFactor    [[0.0, 17.31605724385449], [0.001, 17.28835138...
# TotalDensity  [[-3.769429035186767, 338.803858596419], [-3.7...
# apl           {'200000.0': 66.04924774169922, '201000.0': 64...
# thickness                                              4.284378
#
#                                                             101  \
# FormFactor    [[0.0, 110.40567832366456], [0.001, 110.363314...
# TotalDensity  [[-4.195182552337647, 329.1754387729644], [-4....
# apl           {'100000.0': 59.64723828125, '100020.0': 60.31...
# thickness                                              4.263213
#
#                                                             102  \
# FormFactor    [[0.0, 20.350167778784467], [0.001, 20.3136954...
# TotalDensity  [[-3.9791937465667733, 338.02738118600615], [-...
# apl           {'0.0': 53.1859921875, '100.0': 54.51705078125...
# thickness                                              4.750032
#
#                                                             103  \
# FormFactor    [[0.0, 46.448371511153624], [0.001, 46.4108264...
# TotalDensity  [[-3.857857280731201, 335.8092781725056], [-3....
# apl           {'100000.0078125': 55.20517349243164, '100010....
# thickness                                              4.621177
#
#                                                             106  \
# FormFactor    [[0.0, 51.20403098815298], [0.001, 51.22471131...
# TotalDensity  [[-3.704767187118531, 348.98447238425695], [-3...
# apl           {'0.0': 63.3934375, '100.0': 63.0481591796875,...
# thickness                                              4.304981
#
#                                                             107  \
# FormFactor    [[0.0, 86.43591874913768], [0.001, 86.39792434...
# TotalDensity  [[-3.9933083152771003, 328.2203127086868], [-3...
# apl           {'100000.0': 58.94308090209961, '100020.0': 59...
# thickness                                              4.483715
#
#                                                             108  \
# FormFactor    [[0.0, 18.056393672048046], [0.001, 18.0300569...
# TotalDensity  [[-3.512529983520507, 333.24258420443516], [-3...
# apl           {'0.0': 64.50137329101562, '100.0': 64.5192489...
# thickness                                              4.177063
#
#                                                             109  ...  \
# FormFactor    [[0.0, 13.224406411410294], [0.001, 13.1952126...  ...
# TotalDensity  [[-3.432229001998901, 334.23900393594477], [-3...  ...
# apl           {'135000.0': 62.45389322916667, '135100.0': 62...  ...
# thickness                                               4.24762  ...
#
#                                                             87   \
# FormFactor    [[0.0, 17.273753630461744], [0.001, 17.2534387...
# TotalDensity  [[-3.251855340957641, 330.3774711243143], [-3....
# apl           {'0.0': 70.58169894748264, '100.0': 71.9320882...
# thickness                                              3.895271
#
#                                                             89   \
# FormFactor    [[0.0, 19.549123708967677], [0.001, 19.5224248...
# TotalDensity  [[-3.7740465259552, 332.3840438463952], [-3.73...
# apl           {'0.0': 65.004052734375, '100.0': 64.517705078...
# thickness                                              4.153448
#
#                                                             9    \
# FormFactor    [[0.0, 19.009928045057638], [0.001, 18.9760613...
# TotalDensity  [[-4.08264102935791, 337.4665995321882], [-4.0...
# apl           {'700000.0': 61.41138671875, '700100.0': 60.71...
# thickness                                              4.574268
#
#                                                             90   \
# FormFactor    [[0.0, 11.047130902532333], [0.001, 11.0228171...
# TotalDensity  [[-3.809502771377563, 336.60685842181965], [-3...
# apl           {'0.0': 70.46417236328125, '1000.0': 67.105613...
# thickness                                              4.111844
#
#                                                             91   \
# FormFactor    [[0.0, 37.31489781212652], [0.001, 37.27845054...
# TotalDensity  [[-5.496297426223755, 337.8956631964299], [-5....
# apl           {'200000.0': 42.06497802734375, '201000.0': 41...
# thickness                                               4.83444
#
#                                                             92   \
# FormFactor    [[0.0, 54.944601486624], [0.001, 54.9137411479...
# TotalDensity  [[-4.09386212348938, 336.8302036396125], [-4.0...
# apl           {'100010.0': 61.60816955566406, '100020.0': 62...
# thickness                                              4.337281
#
#                                                             93   \
# FormFactor    [[0.0, 123.65124482935424], [0.001, 123.667489...
# TotalDensity  [[-6.400798763275147, 369.7252820960883], [-6....
# apl           {'100000.0': 61.43149739583333, '100020.0': 61...
# thickness                                              4.381295
#
#                                                             95   \
# FormFactor    [[0.0, 60.04677517642964], [0.001, 60.01194185...
# TotalDensity  [[-3.892557191848754, 337.5673556836723], [-3....
# apl           {'0.0': 62.795857747395836, '20.0': 64.1294826...
# thickness                                               4.46066
#
#                                                             96   \
# FormFactor    [[0.0, 25.40446122064217], [0.001, 25.41730041...
# TotalDensity  [[-3.711015403747558, 323.2462952500889], [-3....
# apl           {'0.0': 61.45030975341797, '10.0': 61.58327102...
# thickness                                                3.5343
#
#                                                             97
# FormFactor    [[0.0, 10.71605352767222], [0.001, 10.69036141...
# TotalDensity  [[-3.01549828338623, 335.22777616799317], [-2....
# apl           {'0.0': 61.85429000854492, '50.0': 62.22754669...
# thickness                                              4.218211
#
# [4 rows x 609 columns]

# %%
from sklearn.preprocessing import StandardScaler

index = np.arange(0,1,0.001)
modified_FF = pd.DataFrame(index=range(1000),columns=[full_df.columns])
modified_FF.index = index

for i in full_df.columns:
    values = []
    for pair in full_df[i]['FormFactor']:
        values.append(round(pair[1],5))
    modified_FF[i] = values
    
modified_FF = (modified_FF-modified_FF.mean())/modified_FF.std()
#modified_FF = StandardScaler().fit_transform(modified_FF)
modified_FF
# Out:
#             1         10        100       101       102       103       106  \
# 0.000  0.001249 -0.441535 -0.537205  0.811462 -0.506604 -0.215030 -0.032003
# 0.001  0.000727 -0.441947 -0.537628  0.810868 -0.507140 -0.215559 -0.031689
# 0.002 -0.000841 -0.443186 -0.538897  0.809086 -0.508748 -0.217149 -0.030746
# 0.003 -0.003452 -0.445249 -0.541011  0.806116 -0.511428 -0.219796 -0.029174
# 0.004 -0.007106 -0.448137 -0.543969  0.801960 -0.515177 -0.223502 -0.026975
# ...         ...       ...       ...       ...       ...       ...       ...
# 0.995 -0.734359 -0.727286 -0.745534 -0.724569 -0.635505 -0.800737 -0.777564
# 0.996 -0.734831 -0.727993 -0.743895 -0.724429 -0.636710 -0.802350 -0.776699
# 0.997 -0.735349 -0.728703 -0.742272 -0.724294 -0.637961 -0.803968 -0.775845
# 0.998 -0.735915 -0.729414 -0.740667 -0.724163 -0.639257 -0.805588 -0.775002
# 0.999 -0.736528 -0.730125 -0.739080 -0.724038 -0.640598 -0.807210 -0.774171
#
#             107       108       109  ...       87        89        9    \
# 0.000  0.619187 -0.419090 -0.541827  ... -0.405719 -0.371208 -0.531057
# 0.001  0.618554 -0.419514 -0.542262  ... -0.406113 -0.371643 -0.531539
# 0.002  0.616653 -0.420787 -0.543566  ... -0.407292 -0.372948 -0.532983
# 0.003  0.613485 -0.422907 -0.545740  ... -0.409257 -0.375122 -0.535390
# 0.004  0.609053 -0.425874 -0.548782  ... -0.412006 -0.378164 -0.538757
# ...         ...       ...       ...  ...       ...       ...       ...
# 0.995 -0.674426 -0.701850 -0.713366  ... -0.701467 -0.678191 -0.718585
# 0.996 -0.675856 -0.701583 -0.712799  ... -0.701845 -0.678098 -0.717451
# 0.997 -0.677339 -0.701318 -0.712240  ... -0.702230 -0.678009 -0.716338
# 0.998 -0.678875 -0.701055 -0.711692  ... -0.702621 -0.677924 -0.715247
# 0.999 -0.680461 -0.700795 -0.711153  ... -0.703019 -0.677843 -0.714179
#
#             90        91        92        93        95        96        97
# 0.000 -0.584007 -0.196622  0.049932  0.873235  0.049266 -0.458394 -0.602427
# 0.001 -0.584411 -0.197227  0.049459  0.873455  0.048763 -0.458164 -0.602829
# 0.002 -0.585624 -0.199041  0.048041  0.874113  0.047256 -0.457475 -0.604034
# 0.003 -0.587644 -0.202064  0.045678  0.875211  0.044745 -0.456327 -0.606042
# 0.004 -0.590472 -0.206293  0.042371  0.876747  0.041231 -0.454720 -0.608852
# ...         ...       ...       ...       ...       ...       ...       ...
# 0.995 -0.757084 -0.701478 -0.763081 -0.752743 -0.721585 -0.735729 -0.750162
# 0.996 -0.758153 -0.703379 -0.762256 -0.752626 -0.719977 -0.734218 -0.749043
# 0.997 -0.759220 -0.705245 -0.761437 -0.752524 -0.718399 -0.732738 -0.747927
# 0.998 -0.760285 -0.707076 -0.760624 -0.752434 -0.716850 -0.731290 -0.746815
# 0.999 -0.761346 -0.708870 -0.759818 -0.752358 -0.715333 -0.729874 -0.745708
#
# [1000 rows x 609 columns]

# %%
index = np.arange(1,196,1)

names = []
for i in full_df.columns:
    names.append(str(i) + 'x')
    names.append(str(i) + 'y')
    
modified_TD = pd.DataFrame(index=range(195),columns=[names])
modified_TD.index = index

for i in full_df.columns:
    x_values = []
    y_values = []
    for pair in full_df[i]['TotalDensity']:
        x_values.append(round(pair[0],5))
        y_values.append(round(pair[1],5))
    
    modified_TD[str(i) + 'x'] = pd.Series(x_values)
    modified_TD[str(i) + 'y'] = pd.Series(y_values)

modified_TD
# Out:
#           1x         1y      10x        10y     100x       100y     101x  \
# 1   -3.28851  329.55363 -3.41331  333.42607 -3.72823  336.40837 -4.14983
# 2   -3.25136  330.32341 -3.37601  333.54101 -3.68704  333.47584 -4.10448
# 3   -3.21420  330.60607 -3.33870  333.28253 -3.64584  340.48865 -4.05912
# 4   -3.17704  329.71469 -3.30140  333.63502 -3.60465  335.66572 -4.01377
# 5   -3.13988  330.56969 -3.26410  333.59900 -3.56345  335.96343 -3.96842
# ..       ...        ...      ...        ...      ...        ...      ...
# 191      NaN        NaN      NaN        NaN      NaN        NaN      NaN
# 192      NaN        NaN      NaN        NaN      NaN        NaN      NaN
# 193      NaN        NaN      NaN        NaN      NaN        NaN      NaN
# 194      NaN        NaN      NaN        NaN      NaN        NaN      NaN
# 195      NaN        NaN      NaN        NaN      NaN        NaN      NaN
#
#           101y     102x       102y  ...      92x        92y      93x  \
# 1    329.13966 -3.93753  337.78165  ... -4.04960  336.72568 -6.33234
# 2    329.20064 -3.89586  336.94098  ... -4.00535  336.37092 -6.26388
# 3    329.59763 -3.85419  337.36216  ... -3.96109  336.58852 -6.19543
# 4    329.26806 -3.81253  337.21659  ... -3.91683  336.41968 -6.12697
# 5    329.44533 -3.77086  337.95780  ... -3.87257  336.25473 -6.05851
# ..         ...      ...        ...  ...      ...        ...      ...
# 191        NaN  3.97919  337.89542  ...      NaN        NaN      NaN
# 192        NaN      NaN        NaN  ...      NaN        NaN      NaN
# 193        NaN      NaN        NaN  ...      NaN        NaN      NaN
# 194        NaN      NaN        NaN  ...      NaN        NaN      NaN
# 195        NaN      NaN        NaN  ...      NaN        NaN      NaN
#
#            93y      95x        95y      96x        96y      97x        97y
# 1    369.66505 -3.85048  337.42870 -3.67175  323.42678 -2.98064  334.90240
# 2    369.51121 -3.80839  337.11402 -3.63248  323.92652 -2.94578  335.51886
# 3    369.35258 -3.76631  336.96882 -3.59321  323.81267 -2.91091  335.34770
# 4    369.80564 -3.72423  337.61269 -3.55394  323.13671 -2.87605  334.93046
# 5    369.55785 -3.68215  338.18583 -3.51467  323.88366 -2.84119  335.75505
# ..         ...      ...        ...      ...        ...      ...        ...
# 191        NaN      NaN        NaN      NaN        NaN      NaN        NaN
# 192        NaN      NaN        NaN      NaN        NaN      NaN        NaN
# 193        NaN      NaN        NaN      NaN        NaN      NaN        NaN
# 194        NaN      NaN        NaN      NaN        NaN      NaN        NaN
# 195        NaN      NaN        NaN      NaN        NaN      NaN        NaN
#
# [195 rows x 1218 columns]

# %%
#modified_TD.isna().sum().value_counts()
# Out:
# 10    174
# 8     170
# 6     144
# 12    132
# 4     120
# 14    100
# 16     80
# 18     64
# 2      56
# 0      48
# 20     40
# 22     32
# 24     22
# 26     12
# 28     10
# 30      4
# 32      4
# 40      2
# 34      2
# 46      2
# dtype: int64

# %%
modified_TD = pd.DataFrame(index=range(185))
modified_TD.index = np.arange(1,186,1)

for i in full_df.columns:
    x_values = []
    y_values = []
    
    for pair in full_df[i]['TotalDensity']:
        x_values.append(round(pair[0],5))
        y_values.append(round(pair[1],5))
        
    if len(x_values) == 186:
        modified_TD[str(i) + 'x'] = pd.Series(x_values)
        modified_TD[str(i) + 'y'] = pd.Series(y_values)

modified_TD
# Out:
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'x'] = pd.Series(x_values)
# C:\Users\niila\AppData\Local\Temp\ipykernel_12992\150329571.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   modified_TD[str(i) + 'y'] = pd.Series(y_values)
#          10x        10y     101x       101y     108x       108y      13x  \
# 1   -3.41331  333.42607 -4.14983  329.13966 -3.47456  333.32801 -3.65943
# 2   -3.37601  333.54101 -4.10448  329.20064 -3.43658  333.28375 -3.61943
# 3   -3.33870  333.28253 -4.05912  329.59763 -3.39861  332.80422 -3.57944
# 4   -3.30140  333.63502 -4.01377  329.26806 -3.36064  333.32165 -3.53945
# 5   -3.26410  333.59900 -3.96842  329.44533 -3.32266  333.61179 -3.49945
# ..       ...        ...      ...        ...      ...        ...      ...
# 181  3.30140  333.45826  4.01377  329.21712  3.36064  333.80461  3.53945
# 182  3.33870  333.30009  4.05912  329.48423  3.39861  333.57961  3.57944
# 183  3.37601  333.05423  4.10448  329.37903  3.43658  333.48605  3.61943
# 184  3.41331  333.57361  4.14983  329.07593  3.47456  333.38742  3.65943
# 185  3.45062  333.45753  4.19518  329.25433  3.51253  333.65891  3.69942
#
#            13y     133x       133y  ...     718x       718y      77x  \
# 1    329.74713 -4.33998  335.94873  ... -5.38083  337.48448 -3.94450
# 2    329.76903 -4.29254  335.52093  ... -5.32202  335.54799 -3.90139
# 3    329.17079 -4.24511  335.89650  ... -5.26321  337.44624 -3.85828
# 4    329.48357 -4.19768  335.92526  ... -5.20441  336.82571 -3.81517
# 5    328.53648 -4.15025  335.57799  ... -5.14560  335.98393 -3.77206
# ..         ...      ...        ...  ...      ...        ...      ...
# 181  329.44570  4.19768  335.73198  ...  5.20441  338.36938  3.81517
# 182  329.76712  4.24511  335.77850  ...  5.26321  335.10676  3.85828
# 183  330.00209  4.29254  335.88038  ...  5.32202  338.70714  3.90139
# 184  329.20167  4.33998  335.76254  ...  5.38083  335.65392  3.94450
# 185  328.39090  4.38741  335.72189  ...  5.43963  336.04810  3.98761
#
#            77y      82x        82y      92x        92y      95x        95y
# 1    342.39481 -3.88095  332.10442 -4.04960  336.72568 -3.85048  337.42870
# 2    342.01759 -3.83853  332.31445 -4.00535  336.37092 -3.80839  337.11402
# 3    341.96571 -3.79612  332.47693 -3.96109  336.58852 -3.76631  336.96882
# 4    342.27830 -3.75370  332.76306 -3.91683  336.41968 -3.72423  337.61269
# 5    342.07990 -3.71129  332.37875 -3.87257  336.25473 -3.68215  338.18583
# ..         ...      ...        ...      ...        ...      ...        ...
# 181  341.78210  3.75370  332.70681  3.91683  336.40658  3.72423  337.44102
# 182  341.93921  3.79612  331.64731  3.96109  337.11124  3.76631  337.39509
# 183  342.00975  3.83853  331.73592  4.00535  336.58064  3.80839  337.81080
# 184  342.04378  3.88095  332.73794  4.04960  336.89465  3.85048  337.61840
# 185  342.04507  3.92336  332.29241  4.09386  336.53418  3.89256  337.44784
#
# [185 rows x 174 columns]

# %%
modified_TD = (modified_TD-modified_TD.mean())/modified_TD.std()
modified_TD
# Out:
#           10x       10y      101x      101y      108x      108y       13x  \
# 1   -1.718050 -0.050939 -1.718051 -0.250525 -1.718053 -0.052433 -1.718052
# 2   -1.699378 -0.048310 -1.699378 -0.249376 -1.699375 -0.053296 -1.699375
# 3   -1.680701 -0.054223 -1.680701 -0.241892 -1.680702 -0.062642 -1.680702
# 4   -1.662028 -0.046159 -1.662028 -0.248105 -1.662030 -0.052557 -1.662029
# 5   -1.643356 -0.046983 -1.643355 -0.244763 -1.643352 -0.046902 -1.643352
# ..        ...       ...       ...       ...       ...       ...       ...
# 181  1.643354 -0.050203  1.643353 -0.249065  1.643355 -0.043144  1.643355
# 182  1.662026 -0.053821  1.662026 -0.244030  1.662028 -0.047529  1.662028
# 183  1.680704 -0.059446  1.680704 -0.246013  1.680701 -0.049353  1.680700
# 184  1.699376 -0.047564  1.699377 -0.251727  1.699379 -0.051275  1.699378
# 185  1.718054 -0.050219  1.718050 -0.248364  1.718051 -0.045984  1.718050
#
#           13y      133x      133y  ...      718x      718y       77x  \
# 1   -0.137021 -1.718053 -0.185281  ... -1.718053 -0.062674 -1.718052
# 2   -0.136576 -1.699375 -0.193693  ... -1.699377 -0.107301 -1.699378
# 3   -0.148739 -1.680701 -0.186308  ... -1.680702 -0.063555 -1.680703
# 4   -0.142380 -1.662027 -0.185742  ... -1.662029 -0.077855 -1.662028
# 5   -0.161635 -1.643353 -0.192571  ... -1.643354 -0.097254 -1.643353
# ..        ...       ...       ...  ...       ...       ...       ...
# 181 -0.143150  1.643353 -0.189543  ...  1.643355 -0.042281  1.643353
# 182 -0.136615  1.662027 -0.188628  ...  1.662027 -0.117469  1.662028
# 183 -0.131837  1.680701 -0.186625  ...  1.680703 -0.034497  1.680703
# 184 -0.148111  1.699378 -0.188942  ...  1.699378 -0.104859  1.699378
# 185 -0.164595  1.718052 -0.189741  ...  1.718050 -0.095775  1.718053
#
#           77y       82x       82y       92x       92y       95x       95y
# 1   -0.140761 -1.718053 -0.167546 -1.718050 -0.126065 -1.718053 -0.137924
# 2   -0.146646 -1.699376 -0.163656 -1.699378 -0.132940 -1.699375 -0.143456
# 3   -0.147455 -1.680704 -0.160647 -1.680703 -0.128723 -1.680701 -0.146009
# 4   -0.142579 -1.662027 -0.155347 -1.662028 -0.131995 -1.662028 -0.134689
# 5   -0.145674 -1.643355 -0.162465 -1.643352 -0.135191 -1.643354 -0.124613
# ..        ...       ...       ...       ...       ...       ...       ...
# 181 -0.150319  1.643353 -0.156389  1.643353 -0.132249  1.643353 -0.137707
# 182 -0.147868  1.662030 -0.176013  1.662029 -0.118594  1.662027 -0.138515
# 183 -0.146768  1.680702 -0.174372  1.680704 -0.128876  1.680701 -0.131206
# 184 -0.146237  1.699379 -0.155812  1.699375 -0.122791  1.699379 -0.134589
# 185 -0.146217  1.718051 -0.164064  1.718050 -0.129776  1.718052 -0.137587
#
# [185 rows x 174 columns]

# %%
names = []
for name in modified_TD.columns:
    if 'x' in name:
        names.append(int(name.replace('x','')))
        continue
print(names)
# Out:
# [10, 101, 108, 13, 133, 137, 157, 158, 161, 171, 174, 177, 185, 2, 200, 207, 213, 237, 248, 251, 262, 267, 269, 273, 289, 291, 294, 297, 299, 3, 324, 33, 332, 339, 347, 350, 351, 355, 358, 360, 394, 400, 420, 433, 434, 435, 436, 439, 447, 450, 452, 488, 492, 494, 497, 50, 503, 510, 511, 512, 516, 535, 536, 541, 552, 561, 591, 592, 595, 596, 6, 60, 619, 651, 655, 663, 667, 674, 676, 708, 710, 712, 718, 77, 82, 92, 95]

# %%
input_data = modified_FF[names]
input_data = input_data.iloc[: , :-7]
input_data
# Out:
#             10        101       108       13        133       137       157  \
# 0.000 -0.441535  0.811462 -0.419090  0.121490  0.483695 -0.265008 -0.520131
# 0.001 -0.441947  0.810868 -0.419514  0.121044  0.483196 -0.265453 -0.520605
# 0.002 -0.443186  0.809086 -0.420787  0.119706  0.481698 -0.266788 -0.522029
# 0.003 -0.445249  0.806116 -0.422907  0.117476  0.479201 -0.269012 -0.524402
# 0.004 -0.448137  0.801960 -0.425874  0.114356  0.475707 -0.272123 -0.527722
# ...         ...       ...       ...       ...       ...       ...       ...
# 0.995 -0.727286 -0.724569 -0.701850 -0.781960 -0.728235 -0.690292 -0.675749
# 0.996 -0.727993 -0.724429 -0.701583 -0.781350 -0.727991 -0.689817 -0.676003
# 0.997 -0.728703 -0.724294 -0.701318 -0.780740 -0.727750 -0.689358 -0.676280
# 0.998 -0.729414 -0.724163 -0.701055 -0.780128 -0.727513 -0.688915 -0.676580
# 0.999 -0.730125 -0.724038 -0.700795 -0.779516 -0.727280 -0.688488 -0.676903
#
#             158       161       171  ...       6         60        619  \
# 0.000 -0.180472  0.049531 -0.488933  ... -0.513892 -0.238238 -0.473306
# 0.001 -0.181069  0.049063 -0.489290  ... -0.514353 -0.238737 -0.473726
# 0.002 -0.182863  0.047659 -0.490361  ... -0.515734 -0.240232 -0.474985
# 0.003 -0.185850  0.045319 -0.492145  ... -0.518037 -0.242724 -0.477082
# 0.004 -0.190030  0.042045 -0.494641  ... -0.521258 -0.246211 -0.480017
# ...         ...       ...       ...  ...       ...       ...       ...
# 0.995 -0.855522 -0.774847 -0.812933  ... -0.857844 -0.820786 -0.742785
# 0.996 -0.858688 -0.774656 -0.812854  ... -0.857907 -0.820963 -0.741743
# 0.997 -0.861838 -0.774457 -0.812611  ... -0.857928 -0.821135 -0.740707
# 0.998 -0.864967 -0.774252 -0.812258  ... -0.857907 -0.821301 -0.739679
# 0.999 -0.868072 -0.774042 -0.811840  ... -0.857847 -0.821461 -0.738658
#
#             651       655       663       667       674       676       708
# 0.000 -0.409288 -0.563482  0.201632 -0.065720 -0.269330 -0.188346 -0.330960
# 0.001 -0.409703 -0.563899  0.201176 -0.065367 -0.269783 -0.187995 -0.331355
# 0.002 -0.410946 -0.565148  0.199808 -0.064309 -0.271143 -0.186943 -0.332542
# 0.003 -0.413018 -0.567230  0.197528 -0.062545 -0.273409 -0.185191 -0.334520
# 0.004 -0.415917 -0.570144  0.194338 -0.060078 -0.276581 -0.182739 -0.337288
# ...         ...       ...       ...       ...       ...       ...       ...
# 0.995 -0.729191 -0.750044 -0.795466 -0.745302 -0.686424 -0.749770 -0.696807
# 0.996 -0.728518 -0.750284 -0.795230 -0.743777 -0.685957 -0.748982 -0.697081
# 0.997 -0.727851 -0.750515 -0.794984 -0.742289 -0.685509 -0.748209 -0.697361
# 0.998 -0.727189 -0.750735 -0.794728 -0.740840 -0.685080 -0.747453 -0.697647
# 0.999 -0.726533 -0.750941 -0.794464 -0.739429 -0.684670 -0.746712 -0.697940
#
# [1000 rows x 80 columns]

# %%
output_data_x = modified_TD.loc[:, modified_TD.columns.str.contains('x')].iloc[: , :-7]
output_data_y = modified_TD.loc[:, modified_TD.columns.str.contains('y')].iloc[: , :-7]
output_data_x
# Out:
#           10x      101x      108x       13x      133x      137x      157x  \
# 1   -1.718050 -1.718051 -1.718053 -1.718052 -1.718053 -1.718051 -1.718052
# 2   -1.699378 -1.699378 -1.699375 -1.699375 -1.699375 -1.699378 -1.699376
# 3   -1.680701 -1.680701 -1.680702 -1.680702 -1.680701 -1.680701 -1.680701
# 4   -1.662028 -1.662028 -1.662030 -1.662029 -1.662027 -1.662028 -1.662026
# 5   -1.643356 -1.643355 -1.643352 -1.643352 -1.643353 -1.643355 -1.643355
# ..        ...       ...       ...       ...       ...       ...       ...
# 181  1.643354  1.643353  1.643355  1.643355  1.643353  1.643354  1.643351
# 182  1.662026  1.662026  1.662028  1.662028  1.662027  1.662026  1.662027
# 183  1.680704  1.680704  1.680701  1.680700  1.680701  1.680703  1.680702
# 184  1.699376  1.699377  1.699379  1.699378  1.699378  1.699376  1.699377
# 185  1.718054  1.718050  1.718051  1.718050  1.718052  1.718053  1.718053
#
#          158x      161x      171x  ...        6x       60x      619x  \
# 1   -1.718050 -1.718052 -1.718051  ... -1.718052 -1.718051 -1.718049
# 2   -1.699375 -1.699376 -1.699377  ... -1.699376 -1.699377 -1.699379
# 3   -1.680701 -1.680704 -1.680704  ... -1.680704 -1.680702 -1.680704
# 4   -1.662027 -1.662028 -1.662025  ... -1.662027 -1.662028 -1.662028
# 5   -1.643353 -1.643352 -1.643352  ... -1.643355 -1.643353 -1.643353
# ..        ...       ...       ...  ...       ...       ...       ...
# 181  1.643352  1.643353  1.643351  ...  1.643353  1.643353  1.643354
# 182  1.662027  1.662030  1.662029  ...  1.662029  1.662028  1.662029
# 183  1.680701  1.680702  1.680703  ...  1.680701  1.680702  1.680704
# 184  1.699375  1.699378  1.699376  ...  1.699378  1.699377  1.699375
# 185  1.718050  1.718050  1.718049  ...  1.718050  1.718051  1.718050
#
#          651x      655x      663x      667x      674x      676x      708x
# 1   -1.718050 -1.718052 -1.718053 -1.718051 -1.718050 -1.718053 -1.718053
# 2   -1.699376 -1.699376 -1.699375 -1.699376 -1.699378 -1.699378 -1.699378
# 3   -1.680701 -1.680700 -1.680701 -1.680701 -1.680701 -1.680702 -1.680703
# 4   -1.662026 -1.662029 -1.662027 -1.662026 -1.662029 -1.662026 -1.662028
# 5   -1.643352 -1.643353 -1.643353 -1.643355 -1.643352 -1.643355 -1.643353
# ..        ...       ...       ...       ...       ...       ...       ...
# 181  1.643352  1.643355  1.643353  1.643351  1.643355  1.643352  1.643354
# 182  1.662027  1.662026  1.662027  1.662027  1.662027  1.662027  1.662029
# 183  1.680701  1.680702  1.680701  1.680702  1.680704  1.680703  1.680704
# 184  1.699376  1.699378  1.699379  1.699377  1.699376  1.699379  1.699378
# 185  1.718050  1.718049  1.718053  1.718052  1.718052  1.718050  1.718053
#
# [185 rows x 80 columns]

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
inputs = keras.Input(shape=(1000,))
dense = layers.Dense(64, activation="relu")
x = dense(inputs)
outputs = layers.Dense(370)(x)
model = keras.Model(inputs=inputs, outputs=outputs)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1000)]            0
#
#  dense (Dense)               (None, 64)                64064
#
#  dense_1 (Dense)             (None, 370)               24050
#
# =================================================================
# Total params: 88,114
# Trainable params: 88,114
# Non-trainable params: 0
# _________________________________________________________________

# %%
import random

names = []
for i in input_data.columns:
    names.append(i[0])

train = random.sample(names,64)
test = []
for number in names:
    if not number in train:
        test.append(number)

print(train)
print(test)
# Out:
# [497, 267, 561, 510, 400, 433, 394, 350, 503, 248, 667, 512, 360, 347, 450, 133, 262, 289, 452, 200, 207, 674, 535, 351, 185, 516, 591, 536, 3, 358, 101, 2, 436, 158, 299, 708, 157, 447, 251, 552, 492, 595, 592, 324, 488, 355, 269, 13, 177, 434, 511, 339, 420, 174, 213, 297, 494, 651, 291, 439, 619, 10, 33, 108]
# [137, 161, 171, 237, 273, 294, 332, 435, 50, 541, 596, 6, 60, 655, 663, 676]

# %%
train_input_values = []
for name in train:
    train_input_values.append(input_data[name].values)

train_output_values = []
for name in train:
    list_1 = output_data[str(name) + 'x'].values
    list_2 = output_data[str(name) + 'y'].values
    train_output_values.append(np.concatenate((list_1,list_2)))
    
test_input_values = []
for name in test:
    test_input_values.append(input_data[name].values)
    
test_output_values = []
for name in test:
    list_1 = output_data[str(name) + 'x'].values
    list_2 = output_data[str(name) + 'y'].values
    test_output_values.append(np.concatenate((list_1,list_2)))
    
train_input_values = np.array(train_input_values)
train_output_values = np.array(train_output_values)
test_input_values = np.array(test_input_values)
test_output_values = np.array(test_output_values)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

inputs = keras.Input(shape=(1000,))
#dense = layers.Dense(64, activation="relu")
x = layers.Dense(128, activation="relu")(inputs)
x = layers.Dropout(0.15, noise_shape = None, seed = 42)(x)
x = layers.Dense(128, activation="relu")(x)
#x = layers.Dense(128, activation="relu")(x)
#x = layers.Dropout(0.2, noise_shape = None, seed = None)(x)
#x = layers.Dense(128, activation="relu")(x)
#x# = layers.Dense(128, activation="relu")(x)
#x = layers.Dense(128, activation="relu")(x)
#dense_2 = layers.Dense(64, activation="relu")
outputs = layers.Dense(370)(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(optimizer='adam', loss='mean_squared_error')

history = model.fit(train_input_values, train_output_values, batch_size=16, epochs=20, validation_split=0.2)
test_scores = model.evaluate(test_input_values, test_output_values, verbose=0)
#print(test_scores)
# Out:
# Epoch 1/20
# 4/4 [==============================] - 1s 47ms/step - loss: 1.0751 - val_loss: 0.7973
# Epoch 2/20
# 4/4 [==============================] - 0s 17ms/step - loss: 0.7350 - val_loss: 0.5497
# Epoch 3/20
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5151 - val_loss: 0.3517
# Epoch 4/20
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3461 - val_loss: 0.2362
# Epoch 5/20
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2397 - val_loss: 0.1758
# Epoch 6/20
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1775 - val_loss: 0.1525
# Epoch 7/20
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1535 - val_loss: 0.1375
# Epoch 8/20
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1358 - val_loss: 0.1292
# Epoch 9/20
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1147 - val_loss: 0.1222
# Epoch 10/20
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1113 - val_loss: 0.1175
# Epoch 11/20
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1029 - val_loss: 0.1217
# Epoch 12/20
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0998 - val_loss: 0.1155
# Epoch 13/20
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1001 - val_loss: 0.1155
# Epoch 14/20
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0963 - val_loss: 0.1240
# Epoch 15/20
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1016 - val_loss: 0.1324
# Epoch 16/20
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1066 - val_loss: 0.1458
# Epoch 17/20
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1143 - val_loss: 0.1293
# Epoch 18/20
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1069 - val_loss: 0.1190
# Epoch 19/20
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1029 - val_loss: 0.1354
# Epoch 20/20
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1047 - val_loss: 0.1148

# %%
#prediction = model.predict(test_input_values)
# Out:
# 1/1 [==============================] - 0s 63ms/step

# %%
prediction = model.predict(test_input_values)
x_1 = prediction[0][0:185]
y_1 = prediction[0][185:]
plt.scatter(x_1,y_1)

x_2 = test_output_values[0][0:185]
y_2 = test_output_values[0][185:]
plt.scatter(x_2,y_2)
plt.show()
# Out:
# 1/1 [==============================] - 0s 55ms/step

# %%
x_1 = prediction[0][0:185]
y_1 = prediction[0][185:]
plt.plot(x_1,y_1)

x_2 = test_output_values[0][0:185]
y_2 = test_output_values[0][185:]
plt.plot(x_2,y_2)
plt.show()
